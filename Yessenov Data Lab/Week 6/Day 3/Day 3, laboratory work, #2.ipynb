# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_excel('data.xlsx', sheet_name=1)

# %%
data.head().T
# Out:
#                                                                            0  \
# Дата                                                     2015-06-01 00:00:00
# Продажи на рынке (кол-во)                                               2098
# Наши продажи (кол-во)                                                    660
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# Unnamed: 11                                                              NaN
# Unnamed: 12                Цель: посчитать продажи на рынке и наши продаж...
# Unnamed: 13                                                              NaN
# Unnamed: 14                                                              NaN
# Unnamed: 15                                                              NaN
# Unnamed: 16                                                              NaN
# Unnamed: 17                                                              NaN
# Unnamed: 18                                                              NaN
#
#                                              1                    2  \
# Дата                       2015-06-02 00:00:00  2015-06-03 00:00:00
# Продажи на рынке (кол-во)                 2050                 1877
# Наши продажи (кол-во)                      694                  729
# Unnamed: 3                                 NaN                  NaN
# Unnamed: 4                                 NaN                  NaN
# Unnamed: 5                                 NaN                  NaN
# Unnamed: 6                                 NaN                  NaN
# Unnamed: 7                                 NaN                  NaN
# Unnamed: 8                                 NaN                  NaN
# Unnamed: 9                                 NaN                  NaN
# Unnamed: 10                                NaN                  NaN
# Unnamed: 11                                NaN                  NaN
# Unnamed: 12                                NaN                  NaN
# Unnamed: 13                                NaN                  NaN
# Unnamed: 14                                NaN                  NaN
# Unnamed: 15                                NaN                  NaN
# Unnamed: 16                                NaN                  NaN
# Unnamed: 17                                NaN                  NaN
# Unnamed: 18                                NaN                  NaN
#
#                                              3                    4
# Дата                       2015-06-04 00:00:00  2015-06-05 00:00:00
# Продажи на рынке (кол-во)                 1709                 1742
# Наши продажи (кол-во)                      733                  737
# Unnamed: 3                                 NaN                  NaN
# Unnamed: 4                                 NaN                  NaN
# Unnamed: 5                                 NaN                  NaN
# Unnamed: 6                                 NaN                  NaN
# Unnamed: 7                                 NaN                  NaN
# Unnamed: 8                                 NaN                  NaN
# Unnamed: 9                                 NaN                  NaN
# Unnamed: 10                                NaN                  NaN
# Unnamed: 11                                NaN                  NaN
# Unnamed: 12                                NaN                  NaN
# Unnamed: 13                                NaN                  NaN
# Unnamed: 14                                NaN                  NaN
# Unnamed: 15                                NaN                  NaN
# Unnamed: 16                                NaN                  NaN
# Unnamed: 17                                NaN                  NaN
# Unnamed: 18                                NaN                  NaN

# %%
data = data[data.columns[:3]]

# %%
data.head()
# Out:
#         Дата  Продажи на рынке (кол-во)  Наши продажи (кол-во)
# 0 2015-06-01                       2098                    660
# 1 2015-06-02                       2050                    694
# 2 2015-06-03                       1877                    729
# 3 2015-06-04                       1709                    733
# 4 2015-06-05                       1742                    737
