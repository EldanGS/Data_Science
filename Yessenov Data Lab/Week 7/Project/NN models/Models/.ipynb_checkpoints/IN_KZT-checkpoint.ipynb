# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
sns.despine()

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import merge
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.layers.advanced_activations import *
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D
from keras.layers.recurrent import LSTM, GRU
from keras import regularizers

import theano
theano.config.compute_test_value = "ignore"
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('ts.csv')
data.head()
# Out:
#        DATE      IN_FOR     OUT_FOR      IN_KZT     OUT_KZT
# 0  1/1/2016         0.0    122953.0   1899647.0   1584705.0
# 1  1/2/2016      2942.0    115059.0   2706416.0   2315761.0
# 2  1/3/2016       263.0    147905.0   3548855.0   2971268.0
# 3  1/4/2016  13533594.0   9363025.0  23528654.0  11716898.0
# 4  1/5/2016  36769881.0  32769452.0  37289979.0  22565273.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 5 columns):
# DATE       731 non-null object
# IN_FOR     731 non-null float64
# OUT_FOR    731 non-null float64
# IN_KZT     731 non-null float64
# OUT_KZT    731 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 28.6+ KB

# %%
def shuffle_in_unison(a, b):
    # courtsey http://stackoverflow.com/users/190280/josh-bleecher-snyder
    assert len(a) == len(b)
    shuffled_a = np.empty(a.shape, dtype=a.dtype)
    shuffled_b = np.empty(b.shape, dtype=b.dtype)
    permutation = np.random.permutation(len(a))
    for old_index, new_index in enumerate(permutation):
        shuffled_a[new_index] = a[old_index]
        shuffled_b[new_index] = b[old_index]
    return shuffled_a, shuffled_b
 
def create_Xt_Yt(X, y, percentage=0.9):
    p = int(len(X) * percentage)
    X_train = X[0:p]
    Y_train = y[0:p]
     
    X_train, Y_train = shuffle_in_unison(X_train, Y_train)
 
    X_test = X[p:]
    Y_test = y[p:]

    return X_train, X_test, Y_train, Y_test

# %%
data0 = data[::-1]
data1 = data0.ix[:, 'IN_KZT'].tolist()

# Uncomment below to use price change time series
# data1 = data0.ix[:, 'IN_FOR'].pct_change().dropna().tolist()

plt.plot(data1)
plt.show()

WINDOW = 30
EMB_SIZE = 1
STEP = 1
FORECAST = 5

# Straightforward way for creating time windows
X, Y = [], []
for i in range(0, len(data1), STEP): 
    try:
        x_i = data1[i:i+WINDOW]
        y_i = data1[i+WINDOW+FORECAST]  

        last_close = x_i[WINDOW-1]
        next_close = y_i

        if last_close < next_close:
            y_i = [1, 0]
        else:
            y_i = [0, 1] 

    except Exception as e:
        print(e)
        break

    X.append(x_i)
    Y.append(y_i)

X = [(np.array(x) - np.mean(x)) / np.std(x) for x in X] # comment it to remove normalization
X, Y = np.array(X), np.array(Y)

X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# list index out of range

# %%
model = Sequential()
model.add(Dense(64, input_dim=30,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())

model.add(Dropout(0.35))
model.add(Dense(16,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dense(2))
model.add(Activation('linear'))

opt = Nadam(lr=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=25, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint(filepath="in_kzt.hdf5", verbose=1, save_best_only=True)
model.compile(optimizer=opt, 
              loss='mean_squared_error',
              metrics=['acc'])

# %%
history = model.fit(X_train, Y_train, 
          nb_epoch = 90, 
          batch_size = 128, 
          verbose=1, 
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr, checkpointer],
          shuffle=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   import sys
# Train on 626 samples, validate on 70 samples
# Epoch 1/90
# 626/626 [==============================] - 1s 1ms/step - loss: 78.4035 - acc: 0.5383 - val_loss: 40.3371 - val_acc: 0.5000
#
# Epoch 00001: val_loss improved from inf to 40.33710, saving model to in_kzt.hdf5
# Epoch 2/90
# 626/626 [==============================] - 0s 32us/step - loss: 71.3779 - acc: 0.5735 - val_loss: 37.9143 - val_acc: 0.5286
#
# Epoch 00002: val_loss improved from 40.33710 to 37.91430, saving model to in_kzt.hdf5
# Epoch 3/90
# 626/626 [==============================] - 0s 31us/step - loss: 65.3692 - acc: 0.5655 - val_loss: 35.4751 - val_acc: 0.5429
#
# Epoch 00003: val_loss improved from 37.91430 to 35.47511, saving model to in_kzt.hdf5
# Epoch 4/90
# 626/626 [==============================] - 0s 57us/step - loss: 60.1096 - acc: 0.5447 - val_loss: 33.1901 - val_acc: 0.5429
#
# Epoch 00004: val_loss improved from 35.47511 to 33.19009, saving model to in_kzt.hdf5
# Epoch 5/90
# 626/626 [==============================] - 0s 43us/step - loss: 55.4125 - acc: 0.5655 - val_loss: 31.0774 - val_acc: 0.5571
#
# Epoch 00005: val_loss improved from 33.19009 to 31.07738, saving model to in_kzt.hdf5
# Epoch 6/90
# 626/626 [==============================] - 0s 41us/step - loss: 50.3059 - acc: 0.5511 - val_loss: 29.1450 - val_acc: 0.6000
#
# Epoch 00006: val_loss improved from 31.07738 to 29.14499, saving model to in_kzt.hdf5
# Epoch 7/90
# 626/626 [==============================] - 0s 25us/step - loss: 46.3471 - acc: 0.5815 - val_loss: 27.3962 - val_acc: 0.5857
#
# Epoch 00007: val_loss improved from 29.14499 to 27.39623, saving model to in_kzt.hdf5
# Epoch 8/90
# 626/626 [==============================] - 0s 29us/step - loss: 43.1694 - acc: 0.5815 - val_loss: 25.7679 - val_acc: 0.5857
#
# Epoch 00008: val_loss improved from 27.39623 to 25.76793, saving model to in_kzt.hdf5
# Epoch 9/90
# 626/626 [==============================] - 0s 39us/step - loss: 40.4353 - acc: 0.5847 - val_loss: 24.2886 - val_acc: 0.5714
#
# Epoch 00009: val_loss improved from 25.76793 to 24.28862, saving model to in_kzt.hdf5
# Epoch 10/90
# 626/626 [==============================] - 0s 31us/step - loss: 37.9842 - acc: 0.5735 - val_loss: 22.9186 - val_acc: 0.5571
#
# Epoch 00010: val_loss improved from 24.28862 to 22.91865, saving model to in_kzt.hdf5
# Epoch 11/90
# 626/626 [==============================] - 0s 43us/step - loss: 35.1059 - acc: 0.5543 - val_loss: 21.6891 - val_acc: 0.5571
#
# Epoch 00011: val_loss improved from 22.91865 to 21.68905, saving model to in_kzt.hdf5
# Epoch 12/90
# 626/626 [==============================] - 0s 36us/step - loss: 32.6042 - acc: 0.5719 - val_loss: 20.5644 - val_acc: 0.5714
#
# Epoch 00012: val_loss improved from 21.68905 to 20.56437, saving model to in_kzt.hdf5
# Epoch 13/90
# 626/626 [==============================] - 0s 27us/step - loss: 31.0377 - acc: 0.5703 - val_loss: 19.5101 - val_acc: 0.5571
#
# Epoch 00013: val_loss improved from 20.56437 to 19.51008, saving model to in_kzt.hdf5
# Epoch 14/90
# 626/626 [==============================] - 0s 53us/step - loss: 29.4258 - acc: 0.5703 - val_loss: 18.5493 - val_acc: 0.5571
#
# Epoch 00014: val_loss improved from 19.51008 to 18.54926, saving model to in_kzt.hdf5
# Epoch 15/90
# 626/626 [==============================] - 0s 41us/step - loss: 27.3270 - acc: 0.5879 - val_loss: 17.6660 - val_acc: 0.5429
#
# Epoch 00015: val_loss improved from 18.54926 to 17.66595, saving model to in_kzt.hdf5
# Epoch 16/90
# 626/626 [==============================] - 0s 46us/step - loss: 26.0311 - acc: 0.5527 - val_loss: 16.8301 - val_acc: 0.5571
#
# Epoch 00016: val_loss improved from 17.66595 to 16.83011, saving model to in_kzt.hdf5
# Epoch 17/90
# 626/626 [==============================] - 0s 30us/step - loss: 24.3166 - acc: 0.5687 - val_loss: 16.0562 - val_acc: 0.5714
#
# Epoch 00017: val_loss improved from 16.83011 to 16.05619, saving model to in_kzt.hdf5
# Epoch 18/90
# 626/626 [==============================] - 0s 48us/step - loss: 23.2900 - acc: 0.5831 - val_loss: 15.3207 - val_acc: 0.5714
#
# Epoch 00018: val_loss improved from 16.05619 to 15.32066, saving model to in_kzt.hdf5
# Epoch 19/90
# 626/626 [==============================] - 0s 53us/step - loss: 22.1567 - acc: 0.5974 - val_loss: 14.6541 - val_acc: 0.5857
#
# Epoch 00019: val_loss improved from 15.32066 to 14.65412, saving model to in_kzt.hdf5
# Epoch 20/90
# 626/626 [==============================] - 0s 38us/step - loss: 21.0355 - acc: 0.5927 - val_loss: 14.0161 - val_acc: 0.6000
#
# Epoch 00020: val_loss improved from 14.65412 to 14.01605, saving model to in_kzt.hdf5
# Epoch 21/90
# 626/626 [==============================] - 0s 33us/step - loss: 19.8226 - acc: 0.5942 - val_loss: 13.4179 - val_acc: 0.6143
#
# Epoch 00021: val_loss improved from 14.01605 to 13.41786, saving model to in_kzt.hdf5
# Epoch 22/90
# 626/626 [==============================] - 0s 43us/step - loss: 19.0175 - acc: 0.5767 - val_loss: 12.8631 - val_acc: 0.5857
#
# Epoch 00022: val_loss improved from 13.41786 to 12.86315, saving model to in_kzt.hdf5
# Epoch 23/90
# 626/626 [==============================] - 0s 37us/step - loss: 18.1552 - acc: 0.5607 - val_loss: 12.3416 - val_acc: 0.5857
#
# Epoch 00023: val_loss improved from 12.86315 to 12.34158, saving model to in_kzt.hdf5
# Epoch 24/90
# 626/626 [==============================] - 0s 26us/step - loss: 17.2350 - acc: 0.5719 - val_loss: 11.8486 - val_acc: 0.6143
#
# Epoch 00024: val_loss improved from 12.34158 to 11.84861, saving model to in_kzt.hdf5
# Epoch 25/90
# 626/626 [==============================] - 0s 48us/step - loss: 16.4732 - acc: 0.5911 - val_loss: 11.3757 - val_acc: 0.5857
#
# Epoch 00025: val_loss improved from 11.84861 to 11.37571, saving model to in_kzt.hdf5
# Epoch 26/90
# 626/626 [==============================] - 0s 89us/step - loss: 15.7342 - acc: 0.6150 - val_loss: 10.9237 - val_acc: 0.5857
#
# Epoch 00026: val_loss improved from 11.37571 to 10.92369, saving model to in_kzt.hdf5
# Epoch 27/90
# 626/626 [==============================] - 0s 56us/step - loss: 15.0912 - acc: 0.5751 - val_loss: 10.4968 - val_acc: 0.5714
#
# Epoch 00027: val_loss improved from 10.92369 to 10.49685, saving model to in_kzt.hdf5
# Epoch 28/90
# 626/626 [==============================] - 0s 29us/step - loss: 14.5352 - acc: 0.5990 - val_loss: 10.0943 - val_acc: 0.5714
#
# Epoch 00028: val_loss improved from 10.49685 to 10.09434, saving model to in_kzt.hdf5
# Epoch 29/90
# 626/626 [==============================] - 0s 47us/step - loss: 13.9723 - acc: 0.5559 - val_loss: 9.7146 - val_acc: 0.5857
#
# Epoch 00029: val_loss improved from 10.09434 to 9.71460, saving model to in_kzt.hdf5
# Epoch 30/90
# 626/626 [==============================] - 0s 38us/step - loss: 13.3180 - acc: 0.6166 - val_loss: 9.3516 - val_acc: 0.5857
#
# Epoch 00030: val_loss improved from 9.71460 to 9.35155, saving model to in_kzt.hdf5
# Epoch 31/90
# 626/626 [==============================] - 0s 42us/step - loss: 12.8754 - acc: 0.6102 - val_loss: 9.0030 - val_acc: 0.5857
#
# Epoch 00031: val_loss improved from 9.35155 to 9.00300, saving model to in_kzt.hdf5
# Epoch 32/90
# 626/626 [==============================] - 0s 32us/step - loss: 12.2835 - acc: 0.6054 - val_loss: 8.6721 - val_acc: 0.5857
#
# Epoch 00032: val_loss improved from 9.00300 to 8.67215, saving model to in_kzt.hdf5
# Epoch 33/90
# 626/626 [==============================] - 0s 36us/step - loss: 11.7995 - acc: 0.6022 - val_loss: 8.3567 - val_acc: 0.5714
#
# Epoch 00033: val_loss improved from 8.67215 to 8.35667, saving model to in_kzt.hdf5
# Epoch 34/90
# 626/626 [==============================] - 0s 32us/step - loss: 11.3333 - acc: 0.5735 - val_loss: 8.0550 - val_acc: 0.5714
#
# Epoch 00034: val_loss improved from 8.35667 to 8.05501, saving model to in_kzt.hdf5
# Epoch 35/90
# 626/626 [==============================] - 0s 34us/step - loss: 10.8618 - acc: 0.5911 - val_loss: 7.7655 - val_acc: 0.5714
#
# Epoch 00035: val_loss improved from 8.05501 to 7.76554, saving model to in_kzt.hdf5
# Epoch 36/90
# 626/626 [==============================] - 0s 34us/step - loss: 10.4540 - acc: 0.6118 - val_loss: 7.4911 - val_acc: 0.5714
#
# Epoch 00036: val_loss improved from 7.76554 to 7.49110, saving model to in_kzt.hdf5
# Epoch 37/90
# 626/626 [==============================] - 0s 38us/step - loss: 10.1833 - acc: 0.5783 - val_loss: 7.2270 - val_acc: 0.5714
#
# Epoch 00037: val_loss improved from 7.49110 to 7.22697, saving model to in_kzt.hdf5
# Epoch 38/90
# 626/626 [==============================] - 0s 44us/step - loss: 9.6731 - acc: 0.6486 - val_loss: 6.9727 - val_acc: 0.6000
#
# Epoch 00038: val_loss improved from 7.22697 to 6.97273, saving model to in_kzt.hdf5
# Epoch 39/90
# 626/626 [==============================] - 0s 55us/step - loss: 9.4318 - acc: 0.6166 - val_loss: 6.7277 - val_acc: 0.6000
#
# Epoch 00039: val_loss improved from 6.97273 to 6.72771, saving model to in_kzt.hdf5
# Epoch 40/90
# 626/626 [==============================] - 0s 57us/step - loss: 9.0862 - acc: 0.6166 - val_loss: 6.4952 - val_acc: 0.6286
#
# Epoch 00040: val_loss improved from 6.72771 to 6.49521, saving model to in_kzt.hdf5
# Epoch 41/90
# 626/626 [==============================] - 0s 87us/step - loss: 8.7462 - acc: 0.6166 - val_loss: 6.2723 - val_acc: 0.6286
#
# Epoch 00041: val_loss improved from 6.49521 to 6.27234, saving model to in_kzt.hdf5
# Epoch 42/90
# 626/626 [==============================] - 0s 77us/step - loss: 8.4270 - acc: 0.6390 - val_loss: 6.0601 - val_acc: 0.6143
#
# Epoch 00042: val_loss improved from 6.27234 to 6.06005, saving model to in_kzt.hdf5
# Epoch 43/90
# 626/626 [==============================] - 0s 30us/step - loss: 8.2519 - acc: 0.6470 - val_loss: 5.8514 - val_acc: 0.6143
#
# Epoch 00043: val_loss improved from 6.06005 to 5.85141, saving model to in_kzt.hdf5
# Epoch 44/90
# 626/626 [==============================] - 0s 30us/step - loss: 7.9060 - acc: 0.6150 - val_loss: 5.6513 - val_acc: 0.6286
#
# Epoch 00044: val_loss improved from 5.85141 to 5.65130, saving model to in_kzt.hdf5
# Epoch 45/90
# 626/626 [==============================] - 0s 25us/step - loss: 7.5878 - acc: 0.6550 - val_loss: 5.4624 - val_acc: 0.6286
#
# Epoch 00045: val_loss improved from 5.65130 to 5.46237, saving model to in_kzt.hdf5
# Epoch 46/90
# 626/626 [==============================] - 0s 29us/step - loss: 7.3322 - acc: 0.6342 - val_loss: 5.2834 - val_acc: 0.6429
#
# Epoch 00046: val_loss improved from 5.46237 to 5.28340, saving model to in_kzt.hdf5
# Epoch 47/90
# 626/626 [==============================] - 0s 29us/step - loss: 7.1330 - acc: 0.6565 - val_loss: 5.1075 - val_acc: 0.6429
#
# Epoch 00047: val_loss improved from 5.28340 to 5.10750, saving model to in_kzt.hdf5
# Epoch 48/90
# 626/626 [==============================] - 0s 27us/step - loss: 6.9471 - acc: 0.6022 - val_loss: 4.9428 - val_acc: 0.6286
#
# Epoch 00048: val_loss improved from 5.10750 to 4.94278, saving model to in_kzt.hdf5
# Epoch 49/90
# 626/626 [==============================] - 0s 29us/step - loss: 6.7273 - acc: 0.6438 - val_loss: 4.7836 - val_acc: 0.6143
#
# Epoch 00049: val_loss improved from 4.94278 to 4.78359, saving model to in_kzt.hdf5
# Epoch 50/90
# 626/626 [==============================] - 0s 65us/step - loss: 6.4327 - acc: 0.6581 - val_loss: 4.6351 - val_acc: 0.6000
#
# Epoch 00050: val_loss improved from 4.78359 to 4.63510, saving model to in_kzt.hdf5
# Epoch 51/90
# 626/626 [==============================] - 0s 57us/step - loss: 6.3072 - acc: 0.6709 - val_loss: 4.4890 - val_acc: 0.5857
#
# Epoch 00051: val_loss improved from 4.63510 to 4.48904, saving model to in_kzt.hdf5
# Epoch 52/90
# 626/626 [==============================] - 0s 29us/step - loss: 6.0311 - acc: 0.6534 - val_loss: 4.3488 - val_acc: 0.5857
#
# Epoch 00052: val_loss improved from 4.48904 to 4.34880, saving model to in_kzt.hdf5
# Epoch 53/90
# 626/626 [==============================] - 0s 27us/step - loss: 5.9056 - acc: 0.6358 - val_loss: 4.2093 - val_acc: 0.6000
#
# Epoch 00053: val_loss improved from 4.34880 to 4.20927, saving model to in_kzt.hdf5
# Epoch 54/90
# 626/626 [==============================] - 0s 33us/step - loss: 5.7326 - acc: 0.6390 - val_loss: 4.0772 - val_acc: 0.5857
#
# Epoch 00054: val_loss improved from 4.20927 to 4.07717, saving model to in_kzt.hdf5
# Epoch 55/90
# 626/626 [==============================] - 0s 25us/step - loss: 5.5763 - acc: 0.6342 - val_loss: 3.9521 - val_acc: 0.5857
#
# Epoch 00055: val_loss improved from 4.07717 to 3.95209, saving model to in_kzt.hdf5
# Epoch 56/90
# 626/626 [==============================] - 0s 35us/step - loss: 5.3470 - acc: 0.6661 - val_loss: 3.8275 - val_acc: 0.5857
#
# Epoch 00056: val_loss improved from 3.95209 to 3.82752, saving model to in_kzt.hdf5
# Epoch 57/90
# 626/626 [==============================] - 0s 32us/step - loss: 5.1899 - acc: 0.6709 - val_loss: 3.7088 - val_acc: 0.5857
#
# Epoch 00057: val_loss improved from 3.82752 to 3.70885, saving model to in_kzt.hdf5
# Epoch 58/90
# 626/626 [==============================] - 0s 26us/step - loss: 5.0570 - acc: 0.6581 - val_loss: 3.5968 - val_acc: 0.5857
#
# Epoch 00058: val_loss improved from 3.70885 to 3.59684, saving model to in_kzt.hdf5
# Epoch 59/90
# 626/626 [==============================] - 0s 28us/step - loss: 4.8575 - acc: 0.6486 - val_loss: 3.4908 - val_acc: 0.5857
#
# Epoch 00059: val_loss improved from 3.59684 to 3.49078, saving model to in_kzt.hdf5
# Epoch 60/90
# 626/626 [==============================] - 0s 34us/step - loss: 4.7222 - acc: 0.6837 - val_loss: 3.3886 - val_acc: 0.5857
#
# Epoch 00060: val_loss improved from 3.49078 to 3.38858, saving model to in_kzt.hdf5
# Epoch 61/90
# 626/626 [==============================] - 0s 33us/step - loss: 4.5926 - acc: 0.6821 - val_loss: 3.2853 - val_acc: 0.5714
#
# Epoch 00061: val_loss improved from 3.38858 to 3.28532, saving model to in_kzt.hdf5
# Epoch 62/90
# 626/626 [==============================] - 0s 28us/step - loss: 4.4752 - acc: 0.6885 - val_loss: 3.1870 - val_acc: 0.5857
#
# Epoch 00062: val_loss improved from 3.28532 to 3.18696, saving model to in_kzt.hdf5
# Epoch 63/90
# 626/626 [==============================] - 0s 28us/step - loss: 4.3429 - acc: 0.6518 - val_loss: 3.0891 - val_acc: 0.6000
#
# Epoch 00063: val_loss improved from 3.18696 to 3.08907, saving model to in_kzt.hdf5
# Epoch 64/90
# 626/626 [==============================] - 0s 42us/step - loss: 4.2290 - acc: 0.6597 - val_loss: 3.0019 - val_acc: 0.6000
#
# Epoch 00064: val_loss improved from 3.08907 to 3.00191, saving model to in_kzt.hdf5
# Epoch 65/90
# 626/626 [==============================] - 0s 69us/step - loss: 4.1278 - acc: 0.6837 - val_loss: 2.9171 - val_acc: 0.6000
#
# Epoch 00065: val_loss improved from 3.00191 to 2.91712, saving model to in_kzt.hdf5
# Epoch 66/90
# 626/626 [==============================] - 0s 70us/step - loss: 4.0142 - acc: 0.6565 - val_loss: 2.8347 - val_acc: 0.6000
#
# Epoch 00066: val_loss improved from 2.91712 to 2.83465, saving model to in_kzt.hdf5
# Epoch 67/90
# 626/626 [==============================] - 0s 70us/step - loss: 3.9114 - acc: 0.6629 - val_loss: 2.7550 - val_acc: 0.5857
#
# Epoch 00067: val_loss improved from 2.83465 to 2.75503, saving model to in_kzt.hdf5
# Epoch 68/90
# 626/626 [==============================] - 0s 82us/step - loss: 3.7668 - acc: 0.7061 - val_loss: 2.6775 - val_acc: 0.5714
#
# Epoch 00068: val_loss improved from 2.75503 to 2.67755, saving model to in_kzt.hdf5
# Epoch 69/90
# 626/626 [==============================] - 0s 68us/step - loss: 3.6753 - acc: 0.6709 - val_loss: 2.5995 - val_acc: 0.5857
#
# Epoch 00069: val_loss improved from 2.67755 to 2.59952, saving model to in_kzt.hdf5
# Epoch 70/90
# 626/626 [==============================] - 0s 73us/step - loss: 3.5828 - acc: 0.6885 - val_loss: 2.5259 - val_acc: 0.5857
#
# Epoch 00070: val_loss improved from 2.59952 to 2.52587, saving model to in_kzt.hdf5
# Epoch 71/90
# 626/626 [==============================] - 0s 77us/step - loss: 3.4898 - acc: 0.6933 - val_loss: 2.4544 - val_acc: 0.5857
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00071: val_loss improved from 2.52587 to 2.45436, saving model to in_kzt.hdf5
# Epoch 72/90
# 626/626 [==============================] - 0s 28us/step - loss: 3.3308 - acc: 0.7157 - val_loss: 2.3932 - val_acc: 0.5571
#
# Epoch 00072: val_loss improved from 2.45436 to 2.39323, saving model to in_kzt.hdf5
# Epoch 73/90
# 626/626 [==============================] - 0s 73us/step - loss: 3.3224 - acc: 0.6773 - val_loss: 2.3345 - val_acc: 0.5571
#
# Epoch 00073: val_loss improved from 2.39323 to 2.33449, saving model to in_kzt.hdf5
# Epoch 74/90
# 626/626 [==============================] - 0s 55us/step - loss: 3.2417 - acc: 0.6965 - val_loss: 2.2787 - val_acc: 0.5714
#
# Epoch 00074: val_loss improved from 2.33449 to 2.27872, saving model to in_kzt.hdf5
# Epoch 75/90
# 626/626 [==============================] - 0s 77us/step - loss: 3.1506 - acc: 0.6933 - val_loss: 2.2230 - val_acc: 0.5857
#
# Epoch 00075: val_loss improved from 2.27872 to 2.22299, saving model to in_kzt.hdf5
# Epoch 76/90
# 626/626 [==============================] - 0s 36us/step - loss: 3.0684 - acc: 0.6901 - val_loss: 2.1676 - val_acc: 0.5857
#
# Epoch 00076: val_loss improved from 2.22299 to 2.16764, saving model to in_kzt.hdf5
# Epoch 77/90
# 626/626 [==============================] - 0s 75us/step - loss: 2.9889 - acc: 0.7109 - val_loss: 2.1145 - val_acc: 0.5857
#
# Epoch 00077: val_loss improved from 2.16764 to 2.11445, saving model to in_kzt.hdf5
# Epoch 78/90
# 626/626 [==============================] - 0s 62us/step - loss: 2.9284 - acc: 0.7364 - val_loss: 2.0625 - val_acc: 0.6000
#
# Epoch 00078: val_loss improved from 2.11445 to 2.06248, saving model to in_kzt.hdf5
# Epoch 79/90
# 626/626 [==============================] - 0s 80us/step - loss: 2.8767 - acc: 0.7077 - val_loss: 2.0132 - val_acc: 0.5857
#
# Epoch 00079: val_loss improved from 2.06248 to 2.01315, saving model to in_kzt.hdf5
# Epoch 80/90
# 626/626 [==============================] - 0s 29us/step - loss: 2.8200 - acc: 0.7125 - val_loss: 1.9630 - val_acc: 0.5857
#
# Epoch 00080: val_loss improved from 2.01315 to 1.96305, saving model to in_kzt.hdf5
# Epoch 81/90
# 626/626 [==============================] - 0s 63us/step - loss: 2.7133 - acc: 0.7284 - val_loss: 1.9175 - val_acc: 0.5857
#
# Epoch 00081: val_loss improved from 1.96305 to 1.91745, saving model to in_kzt.hdf5
# Epoch 82/90
# 626/626 [==============================] - 0s 39us/step - loss: 2.6360 - acc: 0.7013 - val_loss: 1.8721 - val_acc: 0.5857
#
# Epoch 00082: val_loss improved from 1.91745 to 1.87207, saving model to in_kzt.hdf5
# Epoch 83/90
# 626/626 [==============================] - 0s 96us/step - loss: 2.5672 - acc: 0.7316 - val_loss: 1.8279 - val_acc: 0.5857
#
# Epoch 00083: val_loss improved from 1.87207 to 1.82787, saving model to in_kzt.hdf5
# Epoch 84/90
# 626/626 [==============================] - 0s 40us/step - loss: 2.5343 - acc: 0.7540 - val_loss: 1.7856 - val_acc: 0.5429
#
# Epoch 00084: val_loss improved from 1.82787 to 1.78565, saving model to in_kzt.hdf5
# Epoch 85/90
# 626/626 [==============================] - 0s 27us/step - loss: 2.4970 - acc: 0.7204 - val_loss: 1.7439 - val_acc: 0.5571
#
# Epoch 00085: val_loss improved from 1.78565 to 1.74392, saving model to in_kzt.hdf5
# Epoch 86/90
# 626/626 [==============================] - 0s 26us/step - loss: 2.4288 - acc: 0.7125 - val_loss: 1.7030 - val_acc: 0.5714
#
# Epoch 00086: val_loss improved from 1.74392 to 1.70296, saving model to in_kzt.hdf5
# Epoch 87/90
# 626/626 [==============================] - 0s 27us/step - loss: 2.3497 - acc: 0.7077 - val_loss: 1.6656 - val_acc: 0.5857
#
# Epoch 00087: val_loss improved from 1.70296 to 1.66561, saving model to in_kzt.hdf5
# Epoch 88/90
# 626/626 [==============================] - 0s 27us/step - loss: 2.3186 - acc: 0.7204 - val_loss: 1.6283 - val_acc: 0.5714
#
# Epoch 00088: val_loss improved from 1.66561 to 1.62826, saving model to in_kzt.hdf5
# Epoch 89/90
# 626/626 [==============================] - 0s 37us/step - loss: 2.2726 - acc: 0.7460 - val_loss: 1.5914 - val_acc: 0.5714
#
# Epoch 00089: val_loss improved from 1.62826 to 1.59141, saving model to in_kzt.hdf5
# Epoch 90/90
# 626/626 [==============================] - 0s 65us/step - loss: 2.1866 - acc: 0.7428 - val_loss: 1.5551 - val_acc: 0.5714
#
# Epoch 00090: val_loss improved from 1.59141 to 1.55513, saving model to in_kzt.hdf5

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
