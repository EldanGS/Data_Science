# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
sns.despine()

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import merge
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.layers.advanced_activations import *
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D
from keras.layers.recurrent import LSTM, GRU
from keras import regularizers
import keras.backend as K

import theano
theano.config.compute_test_value = "ignore"
# %matplotlib inline

# %%
data = pd.read_csv('ts.csv')
data.head()
# Out:
#        DATE      IN_FOR     OUT_FOR      IN_KZT     OUT_KZT
# 0  1/1/2016         0.0    122953.0   1899647.0   1584705.0
# 1  1/2/2016      2942.0    115059.0   2706416.0   2315761.0
# 2  1/3/2016       263.0    147905.0   3548855.0   2971268.0
# 3  1/4/2016  13533594.0   9363025.0  23528654.0  11716898.0
# 4  1/5/2016  36769881.0  32769452.0  37289979.0  22565273.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 5 columns):
# DATE       731 non-null object
# IN_FOR     731 non-null float64
# OUT_FOR    731 non-null float64
# IN_KZT     731 non-null float64
# OUT_KZT    731 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 28.6+ KB

# %%
def shuffle_in_unison(a, b):
    # courtsey http://stackoverflow.com/users/190280/josh-bleecher-snyder
    assert len(a) == len(b)
    shuffled_a = np.empty(a.shape, dtype=a.dtype)
    shuffled_b = np.empty(b.shape, dtype=b.dtype)
    permutation = np.random.permutation(len(a))
    
    for old_index, new_index in enumerate(permutation):
        shuffled_a[new_index] = a[old_index]
        shuffled_b[new_index] = b[old_index]
    
    return shuffled_a, shuffled_b
 
def create_Xt_Yt(X, y, percentage=0.9):
    p = int(len(X) * percentage)
    X_train = X[0:p]
    Y_train = y[0:p]
     
    X_train, Y_train = shuffle_in_unison(X_train, Y_train)
 
    X_test = X[p:]
    Y_test = y[p:]

    return X_train, X_test, Y_train, Y_test

# %% [markdown]
# # IN_FOR

# %%
data0 = data[::-1]
data1 = data0.ix[:, 'IN_FOR'].tolist()

# Uncomment below to use price change time series
# data1 = data0.ix[:, 'IN_FOR'].pct_change().dropna().tolist()

plt.figure(figsize=(15, 5))
plt.plot(data1)
plt.xlabel('DAYS')
plt.ylabel('IN FOR')
plt.show()

WINDOW = 30
EMB_SIZE = 1
STEP = 1
FORECAST = 1

# Straightforward way for creating time windows
X, Y = [], []
for i in range(0, len(data1), STEP): 
    try:
        x_i = data1[i:i+WINDOW]
        y_i = data1[i+WINDOW+FORECAST]  

        last_close = x_i[WINDOW-1]
        next_close = y_i

        if last_close < next_close:
            y_i = [1, 0]
        else:
            y_i = [0, 1] 

    except Exception as e:
        print(e)
        break

    X.append(x_i)
    Y.append(y_i)

X = [(np.array(x) - np.mean(x)) / np.std(x) for x in X] # comment it to remove normalization
X, Y = np.array(X), np.array(Y)

X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# list index out of range

# %%
def root_mean_squared_error(y_true, y_pred):
    return (K.sqrt(K.mean(K.square(y_pred - y_true), axis = -1)))

# %%
model = Sequential()
model.add(Dense(64, input_dim = 30,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())

model.add(Dropout(0.5))
model.add(Dense(16,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())

model.add(Dense(2))
model.add(Activation('softmax'))

opt = Nadam(lr=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=25, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint(filepath="in_for.hdf5", verbose=1, save_best_only=True)
model.compile(optimizer=opt, 
              loss=root_mean_squared_error,
              metrics=['acc'])

# %%
history = model.fit(X_train, Y_train, 
          nb_epoch = 110, 
          batch_size = 128, 
          verbose=1, 
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr, checkpointer],
          shuffle=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   import sys
# Train on 630 samples, validate on 70 samples
# Epoch 1/110
# 630/630 [==============================] - 3s 5ms/step - loss: 86.4699 - acc: 0.5476 - val_loss: 37.6706 - val_acc: 0.4429
#
# Epoch 00001: val_loss improved from inf to 37.67057, saving model to in_for.hdf5
# Epoch 2/110
# 630/630 [==============================] - 0s 43us/step - loss: 81.1964 - acc: 0.5635 - val_loss: 35.2642 - val_acc: 0.4571
#
# Epoch 00002: val_loss improved from 37.67057 to 35.26418, saving model to in_for.hdf5
# Epoch 3/110
# 630/630 [==============================] - 0s 40us/step - loss: 76.9996 - acc: 0.5365 - val_loss: 32.8531 - val_acc: 0.4571
#
# Epoch 00003: val_loss improved from 35.26418 to 32.85308, saving model to in_for.hdf5
# Epoch 4/110
# 630/630 [==============================] - 0s 41us/step - loss: 71.6937 - acc: 0.5508 - val_loss: 30.6056 - val_acc: 0.4429
#
# Epoch 00004: val_loss improved from 32.85308 to 30.60559, saving model to in_for.hdf5
# Epoch 5/110
# 630/630 [==============================] - 0s 58us/step - loss: 66.4446 - acc: 0.5270 - val_loss: 28.5446 - val_acc: 0.4429
#
# Epoch 00005: val_loss improved from 30.60559 to 28.54461, saving model to in_for.hdf5
# Epoch 6/110
# 630/630 [==============================] - 0s 55us/step - loss: 62.4316 - acc: 0.5270 - val_loss: 26.6527 - val_acc: 0.4286
#
# Epoch 00006: val_loss improved from 28.54461 to 26.65270, saving model to in_for.hdf5
# Epoch 7/110
# 630/630 [==============================] - 0s 40us/step - loss: 58.4074 - acc: 0.5635 - val_loss: 24.9336 - val_acc: 0.4429
#
# Epoch 00007: val_loss improved from 26.65270 to 24.93362, saving model to in_for.hdf5
# Epoch 8/110
# 630/630 [==============================] - 0s 49us/step - loss: 54.0830 - acc: 0.5333 - val_loss: 23.3732 - val_acc: 0.4000
#
# Epoch 00008: val_loss improved from 24.93362 to 23.37321, saving model to in_for.hdf5
# Epoch 9/110
# 630/630 [==============================] - 0s 55us/step - loss: 51.1727 - acc: 0.5270 - val_loss: 21.9550 - val_acc: 0.4143
#
# Epoch 00009: val_loss improved from 23.37321 to 21.95498, saving model to in_for.hdf5
# Epoch 10/110
# 630/630 [==============================] - 0s 41us/step - loss: 47.8468 - acc: 0.5397 - val_loss: 20.6563 - val_acc: 0.4143
#
# Epoch 00010: val_loss improved from 21.95498 to 20.65631, saving model to in_for.hdf5
# Epoch 11/110
# 630/630 [==============================] - 0s 38us/step - loss: 45.0325 - acc: 0.5730 - val_loss: 19.4561 - val_acc: 0.4286
#
# Epoch 00011: val_loss improved from 20.65631 to 19.45613, saving model to in_for.hdf5
# Epoch 12/110
# 630/630 [==============================] - 0s 73us/step - loss: 42.6500 - acc: 0.5159 - val_loss: 18.3704 - val_acc: 0.4429
#
# Epoch 00012: val_loss improved from 19.45613 to 18.37040, saving model to in_for.hdf5
# Epoch 13/110
# 630/630 [==============================] - 0s 73us/step - loss: 39.9810 - acc: 0.4968 - val_loss: 17.3585 - val_acc: 0.4571
#
# Epoch 00013: val_loss improved from 18.37040 to 17.35851, saving model to in_for.hdf5
# Epoch 14/110
# 630/630 [==============================] - 0s 43us/step - loss: 38.2509 - acc: 0.5270 - val_loss: 16.4395 - val_acc: 0.4714
#
# Epoch 00014: val_loss improved from 17.35851 to 16.43948, saving model to in_for.hdf5
# Epoch 15/110
# 630/630 [==============================] - 0s 45us/step - loss: 35.3218 - acc: 0.5016 - val_loss: 15.5874 - val_acc: 0.4857
#
# Epoch 00015: val_loss improved from 16.43948 to 15.58735, saving model to in_for.hdf5
# Epoch 16/110
# 630/630 [==============================] - 0s 58us/step - loss: 33.4438 - acc: 0.5238 - val_loss: 14.8007 - val_acc: 0.4857
#
# Epoch 00016: val_loss improved from 15.58735 to 14.80073, saving model to in_for.hdf5
# Epoch 17/110
# 630/630 [==============================] - 0s 42us/step - loss: 32.0502 - acc: 0.5349 - val_loss: 14.0641 - val_acc: 0.4857
#
# Epoch 00017: val_loss improved from 14.80073 to 14.06411, saving model to in_for.hdf5
# Epoch 18/110
# 630/630 [==============================] - 0s 49us/step - loss: 30.3369 - acc: 0.5254 - val_loss: 13.3782 - val_acc: 0.5000
#
# Epoch 00018: val_loss improved from 14.06411 to 13.37819, saving model to in_for.hdf5
# Epoch 19/110
# 630/630 [==============================] - 0s 42us/step - loss: 28.5553 - acc: 0.5127 - val_loss: 12.7331 - val_acc: 0.5000
#
# Epoch 00019: val_loss improved from 13.37819 to 12.73310, saving model to in_for.hdf5
# Epoch 20/110
# 630/630 [==============================] - 0s 40us/step - loss: 27.5256 - acc: 0.5444 - val_loss: 12.1321 - val_acc: 0.5000
#
# Epoch 00020: val_loss improved from 12.73310 to 12.13205, saving model to in_for.hdf5
# Epoch 21/110
# 630/630 [==============================] - 0s 54us/step - loss: 25.8757 - acc: 0.5556 - val_loss: 11.5752 - val_acc: 0.4857
#
# Epoch 00021: val_loss improved from 12.13205 to 11.57523, saving model to in_for.hdf5
# Epoch 22/110
# 630/630 [==============================] - 0s 83us/step - loss: 24.3953 - acc: 0.5381 - val_loss: 11.0524 - val_acc: 0.4857
#
# Epoch 00022: val_loss improved from 11.57523 to 11.05243, saving model to in_for.hdf5
# Epoch 23/110
# 630/630 [==============================] - 0s 49us/step - loss: 23.3416 - acc: 0.5238 - val_loss: 10.5644 - val_acc: 0.5000
#
# Epoch 00023: val_loss improved from 11.05243 to 10.56440, saving model to in_for.hdf5
# Epoch 24/110
# 630/630 [==============================] - 0s 41us/step - loss: 22.2123 - acc: 0.5476 - val_loss: 10.0995 - val_acc: 0.5000
#
# Epoch 00024: val_loss improved from 10.56440 to 10.09953, saving model to in_for.hdf5
# Epoch 25/110
# 630/630 [==============================] - 0s 40us/step - loss: 21.0476 - acc: 0.5492 - val_loss: 9.6667 - val_acc: 0.5000
#
# Epoch 00025: val_loss improved from 10.09953 to 9.66667, saving model to in_for.hdf5
# Epoch 26/110
# 630/630 [==============================] - 0s 47us/step - loss: 20.0927 - acc: 0.5413 - val_loss: 9.2577 - val_acc: 0.5000
#
# Epoch 00026: val_loss improved from 9.66667 to 9.25767, saving model to in_for.hdf5
# Epoch 27/110
# 630/630 [==============================] - 0s 53us/step - loss: 19.1127 - acc: 0.5556 - val_loss: 8.8712 - val_acc: 0.4857
#
# Epoch 00027: val_loss improved from 9.25767 to 8.87125, saving model to in_for.hdf5
# Epoch 28/110
# 630/630 [==============================] - 0s 57us/step - loss: 18.5147 - acc: 0.5603 - val_loss: 8.5084 - val_acc: 0.5143
#
# Epoch 00028: val_loss improved from 8.87125 to 8.50842, saving model to in_for.hdf5
# Epoch 29/110
# 630/630 [==============================] - 0s 48us/step - loss: 17.5405 - acc: 0.5444 - val_loss: 8.1660 - val_acc: 0.5000
#
# Epoch 00029: val_loss improved from 8.50842 to 8.16604, saving model to in_for.hdf5
# Epoch 30/110
# 630/630 [==============================] - 0s 57us/step - loss: 16.9047 - acc: 0.5286 - val_loss: 7.8421 - val_acc: 0.5143
#
# Epoch 00030: val_loss improved from 8.16604 to 7.84206, saving model to in_for.hdf5
# Epoch 31/110
# 630/630 [==============================] - 0s 49us/step - loss: 15.9403 - acc: 0.5397 - val_loss: 7.5365 - val_acc: 0.5143
#
# Epoch 00031: val_loss improved from 7.84206 to 7.53649, saving model to in_for.hdf5
# Epoch 32/110
# 630/630 [==============================] - 0s 57us/step - loss: 15.2675 - acc: 0.5603 - val_loss: 7.2502 - val_acc: 0.5429
#
# Epoch 00032: val_loss improved from 7.53649 to 7.25018, saving model to in_for.hdf5
# Epoch 33/110
# 630/630 [==============================] - 0s 41us/step - loss: 14.7650 - acc: 0.5762 - val_loss: 6.9768 - val_acc: 0.5286
#
# Epoch 00033: val_loss improved from 7.25018 to 6.97679, saving model to in_for.hdf5
# Epoch 34/110
# 630/630 [==============================] - 0s 39us/step - loss: 14.2088 - acc: 0.5635 - val_loss: 6.7205 - val_acc: 0.5286
#
# Epoch 00034: val_loss improved from 6.97679 to 6.72047, saving model to in_for.hdf5
# Epoch 35/110
# 630/630 [==============================] - 0s 50us/step - loss: 13.5972 - acc: 0.5302 - val_loss: 6.4719 - val_acc: 0.5143
#
# Epoch 00035: val_loss improved from 6.72047 to 6.47191, saving model to in_for.hdf5
# Epoch 36/110
# 630/630 [==============================] - 0s 40us/step - loss: 12.7977 - acc: 0.5349 - val_loss: 6.2343 - val_acc: 0.5429
#
# Epoch 00036: val_loss improved from 6.47191 to 6.23435, saving model to in_for.hdf5
# Epoch 37/110
# 630/630 [==============================] - 0s 41us/step - loss: 12.3368 - acc: 0.5651 - val_loss: 6.0071 - val_acc: 0.5286
# Epoch 00037: val_loss improved from 6.23435 to 6.00708, saving model to in_for.hdf5
# Epoch 38/110
# 630/630 [==============================] - 0s 33us/step - loss: 11.9290 - acc: 0.5651 - val_loss: 5.7940 - val_acc: 0.5143
#
# Epoch 00038: val_loss improved from 6.00708 to 5.79400, saving model to in_for.hdf5
# Epoch 39/110
# 630/630 [==============================] - 0s 40us/step - loss: 11.4050 - acc: 0.5603 - val_loss: 5.5895 - val_acc: 0.5286
#
# Epoch 00039: val_loss improved from 5.79400 to 5.58950, saving model to in_for.hdf5
# Epoch 40/110
# 630/630 [==============================] - 0s 32us/step - loss: 10.9099 - acc: 0.5492 - val_loss: 5.3985 - val_acc: 0.5571
#
# Epoch 00040: val_loss improved from 5.58950 to 5.39849, saving model to in_for.hdf5
# Epoch 41/110
# 630/630 [==============================] - 0s 37us/step - loss: 10.4622 - acc: 0.5571 - val_loss: 5.2155 - val_acc: 0.5571
#
# Epoch 00041: val_loss improved from 5.39849 to 5.21551, saving model to in_for.hdf5
# Epoch 42/110
# 630/630 [==============================] - 0s 37us/step - loss: 10.1307 - acc: 0.5651 - val_loss: 5.0377 - val_acc: 0.5286
#
# Epoch 00042: val_loss improved from 5.21551 to 5.03770, saving model to in_for.hdf5
# Epoch 43/110
# 630/630 [==============================] - 0s 38us/step - loss: 9.7202 - acc: 0.5825 - val_loss: 4.8672 - val_acc: 0.5714
#
# Epoch 00043: val_loss improved from 5.03770 to 4.86725, saving model to in_for.hdf5
# Epoch 44/110
# 630/630 [==============================] - 0s 34us/step - loss: 9.2425 - acc: 0.5730 - val_loss: 4.7042 - val_acc: 0.5714
#
# Epoch 00044: val_loss improved from 4.86725 to 4.70417, saving model to in_for.hdf5
# Epoch 45/110
# 630/630 [==============================] - 0s 34us/step - loss: 8.9911 - acc: 0.5984 - val_loss: 4.5507 - val_acc: 0.5571
#
# Epoch 00045: val_loss improved from 4.70417 to 4.55070, saving model to in_for.hdf5
# Epoch 46/110
# 630/630 [==============================] - 0s 36us/step - loss: 8.6514 - acc: 0.5968 - val_loss: 4.4049 - val_acc: 0.5714
#
# Epoch 00046: val_loss improved from 4.55070 to 4.40486, saving model to in_for.hdf5
# Epoch 47/110
# 630/630 [==============================] - 0s 35us/step - loss: 8.2870 - acc: 0.6048 - val_loss: 4.2613 - val_acc: 0.5571
#
# Epoch 00047: val_loss improved from 4.40486 to 4.26133, saving model to in_for.hdf5
# Epoch 48/110
# 630/630 [==============================] - 0s 32us/step - loss: 7.9945 - acc: 0.5984 - val_loss: 4.1245 - val_acc: 0.5429
#
# Epoch 00048: val_loss improved from 4.26133 to 4.12452, saving model to in_for.hdf5
# Epoch 49/110
# 630/630 [==============================] - 0s 33us/step - loss: 7.6654 - acc: 0.5841 - val_loss: 3.9941 - val_acc: 0.5286
#
# Epoch 00049: val_loss improved from 4.12452 to 3.99414, saving model to in_for.hdf5
# Epoch 50/110
# 630/630 [==============================] - 0s 35us/step - loss: 7.3805 - acc: 0.5508 - val_loss: 3.8684 - val_acc: 0.5714
#
# Epoch 00050: val_loss improved from 3.99414 to 3.86839, saving model to in_for.hdf5
# Epoch 51/110
# 630/630 [==============================] - 0s 37us/step - loss: 7.1325 - acc: 0.5889 - val_loss: 3.7463 - val_acc: 0.5714
#
# Epoch 00051: val_loss improved from 3.86839 to 3.74625, saving model to in_for.hdf5
# Epoch 52/110
# 630/630 [==============================] - 0s 33us/step - loss: 6.9187 - acc: 0.5683 - val_loss: 3.6308 - val_acc: 0.6000
#
# Epoch 00052: val_loss improved from 3.74625 to 3.63083, saving model to in_for.hdf5
# Epoch 53/110
# 630/630 [==============================] - 0s 33us/step - loss: 6.6119 - acc: 0.6444 - val_loss: 3.5194 - val_acc: 0.6143
#
# Epoch 00053: val_loss improved from 3.63083 to 3.51940, saving model to in_for.hdf5
# Epoch 54/110
# 630/630 [==============================] - 0s 34us/step - loss: 6.3373 - acc: 0.5778 - val_loss: 3.4113 - val_acc: 0.6143
#
# Epoch 00054: val_loss improved from 3.51940 to 3.41130, saving model to in_for.hdf5
# Epoch 55/110
# 630/630 [==============================] - 0s 36us/step - loss: 6.1975 - acc: 0.5937 - val_loss: 3.3091 - val_acc: 0.6143
#
# Epoch 00055: val_loss improved from 3.41130 to 3.30909, saving model to in_for.hdf5
# Epoch 56/110
# 630/630 [==============================] - 0s 33us/step - loss: 5.9029 - acc: 0.5857 - val_loss: 3.2110 - val_acc: 0.6143
#
# Epoch 00056: val_loss improved from 3.30909 to 3.21102, saving model to in_for.hdf5
# Epoch 57/110
# 630/630 [==============================] - 0s 34us/step - loss: 5.7065 - acc: 0.5921 - val_loss: 3.1136 - val_acc: 0.6143
#
# Epoch 00057: val_loss improved from 3.21102 to 3.11362, saving model to in_for.hdf5
# Epoch 58/110
# 630/630 [==============================] - 0s 33us/step - loss: 5.5408 - acc: 0.6397 - val_loss: 3.0249 - val_acc: 0.6143
#
# Epoch 00058: val_loss improved from 3.11362 to 3.02487, saving model to in_for.hdf5
# Epoch 59/110
# 630/630 [==============================] - 0s 36us/step - loss: 5.3347 - acc: 0.6349 - val_loss: 2.9354 - val_acc: 0.6143
#
# Epoch 00059: val_loss improved from 3.02487 to 2.93536, saving model to in_for.hdf5
# Epoch 60/110
# 630/630 [==============================] - 0s 38us/step - loss: 5.1614 - acc: 0.6238 - val_loss: 2.8506 - val_acc: 0.6286
#
# Epoch 00060: val_loss improved from 2.93536 to 2.85055, saving model to in_for.hdf5
# Epoch 61/110
# 630/630 [==============================] - 0s 36us/step - loss: 5.0049 - acc: 0.6159 - val_loss: 2.7677 - val_acc: 0.6143
#
# Epoch 00061: val_loss improved from 2.85055 to 2.76773, saving model to in_for.hdf5
# Epoch 62/110
# 630/630 [==============================] - 0s 40us/step - loss: 4.8569 - acc: 0.5889 - val_loss: 2.6863 - val_acc: 0.6429
#
# Epoch 00062: val_loss improved from 2.76773 to 2.68635, saving model to in_for.hdf5
# Epoch 63/110
# 630/630 [==============================] - 0s 42us/step - loss: 4.6403 - acc: 0.6397 - val_loss: 2.6095 - val_acc: 0.6429
#
# Epoch 00063: val_loss improved from 2.68635 to 2.60946, saving model to in_for.hdf5
# Epoch 64/110
# 630/630 [==============================] - 0s 42us/step - loss: 4.4973 - acc: 0.6619 - val_loss: 2.5346 - val_acc: 0.6429
#
# Epoch 00064: val_loss improved from 2.60946 to 2.53456, saving model to in_for.hdf5
# Epoch 65/110
# 630/630 [==============================] - 0s 44us/step - loss: 4.3300 - acc: 0.6397 - val_loss: 2.4634 - val_acc: 0.6714
#
# Epoch 00065: val_loss improved from 2.53456 to 2.46336, saving model to in_for.hdf5
# Epoch 66/110
# 630/630 [==============================] - 0s 36us/step - loss: 4.2080 - acc: 0.6635 - val_loss: 2.3933 - val_acc: 0.6571
#
# Epoch 00066: val_loss improved from 2.46336 to 2.39327, saving model to in_for.hdf5
# Epoch 67/110
# 630/630 [==============================] - 0s 40us/step - loss: 4.0417 - acc: 0.6698 - val_loss: 2.3269 - val_acc: 0.6286
#
# Epoch 00067: val_loss improved from 2.39327 to 2.32691, saving model to in_for.hdf5
# Epoch 68/110
# 630/630 [==============================] - 0s 40us/step - loss: 3.8905 - acc: 0.6714 - val_loss: 2.2617 - val_acc: 0.6714
#
# Epoch 00068: val_loss improved from 2.32691 to 2.26172, saving model to in_for.hdf5
# Epoch 69/110
# 630/630 [==============================] - 0s 47us/step - loss: 3.7426 - acc: 0.6635 - val_loss: 2.1974 - val_acc: 0.6571
#
# Epoch 00069: val_loss improved from 2.26172 to 2.19740, saving model to in_for.hdf5
# Epoch 70/110
# 630/630 [==============================] - 0s 42us/step - loss: 3.6103 - acc: 0.6698 - val_loss: 2.1366 - val_acc: 0.7000
#
# Epoch 00070: val_loss improved from 2.19740 to 2.13657, saving model to in_for.hdf5
# Epoch 71/110
# 630/630 [==============================] - 0s 33us/step - loss: 3.5440 - acc: 0.6857 - val_loss: 2.0787 - val_acc: 0.7000
#
# Epoch 00071: val_loss improved from 2.13657 to 2.07871, saving model to in_for.hdf5
# Epoch 72/110
# 630/630 [==============================] - 0s 43us/step - loss: 3.4202 - acc: 0.6746 - val_loss: 2.0207 - val_acc: 0.6857
#
# Epoch 00072: val_loss improved from 2.07871 to 2.02072, saving model to in_for.hdf5
# Epoch 73/110
# 630/630 [==============================] - 0s 39us/step - loss: 3.2769 - acc: 0.6794 - val_loss: 1.9654 - val_acc: 0.7286
#
# Epoch 00073: val_loss improved from 2.02072 to 1.96539, saving model to in_for.hdf5
# Epoch 74/110
# 630/630 [==============================] - 0s 41us/step - loss: 3.1968 - acc: 0.6730 - val_loss: 1.9111 - val_acc: 0.7286
#
# Epoch 00074: val_loss improved from 1.96539 to 1.91113, saving model to in_for.hdf5
# Epoch 75/110
# 630/630 [==============================] - 0s 40us/step - loss: 3.1171 - acc: 0.7032 - val_loss: 1.8585 - val_acc: 0.7143
#
# Epoch 00075: val_loss improved from 1.91113 to 1.85849, saving model to in_for.hdf5
# Epoch 76/110
# 630/630 [==============================] - 0s 40us/step - loss: 2.9813 - acc: 0.7190 - val_loss: 1.8128 - val_acc: 0.6857
#
# Epoch 00076: val_loss improved from 1.85849 to 1.81281, saving model to in_for.hdf5
# Epoch 77/110
# 630/630 [==============================] - 0s 35us/step - loss: 2.8878 - acc: 0.7032 - val_loss: 1.7631 - val_acc: 0.7000
#
# Epoch 00077: val_loss improved from 1.81281 to 1.76309, saving model to in_for.hdf5
# Epoch 78/110
# 630/630 [==============================] - 0s 36us/step - loss: 2.7785 - acc: 0.6889 - val_loss: 1.7159 - val_acc: 0.7000
#
# Epoch 00078: val_loss improved from 1.76309 to 1.71589, saving model to in_for.hdf5
# Epoch 79/110
# 630/630 [==============================] - 0s 34us/step - loss: 2.7169 - acc: 0.7016 - val_loss: 1.6709 - val_acc: 0.7143
#
# Epoch 00079: val_loss improved from 1.71589 to 1.67088, saving model to in_for.hdf5
# Epoch 80/110
# 630/630 [==============================] - 0s 36us/step - loss: 2.6023 - acc: 0.7302 - val_loss: 1.6265 - val_acc: 0.7143
#
# Epoch 00080: val_loss improved from 1.67088 to 1.62654, saving model to in_for.hdf5
# Epoch 81/110
# 630/630 [==============================] - 0s 33us/step - loss: 2.5599 - acc: 0.6778 - val_loss: 1.5833 - val_acc: 0.7000
#
# Epoch 00081: val_loss improved from 1.62654 to 1.58333, saving model to in_for.hdf5
# Epoch 82/110
# 630/630 [==============================] - 0s 35us/step - loss: 2.4607 - acc: 0.7095 - val_loss: 1.5452 - val_acc: 0.7000
#
# Epoch 00082: val_loss improved from 1.58333 to 1.54519, saving model to in_for.hdf5
# Epoch 83/110
# 630/630 [==============================] - 0s 40us/step - loss: 2.3736 - acc: 0.7349 - val_loss: 1.5044 - val_acc: 0.7000
#
# Epoch 00083: val_loss improved from 1.54519 to 1.50443, saving model to in_for.hdf5
# Epoch 84/110
# 630/630 [==============================] - 0s 42us/step - loss: 2.3206 - acc: 0.7048 - val_loss: 1.4659 - val_acc: 0.7000
#
# Epoch 00084: val_loss improved from 1.50443 to 1.46588, saving model to in_for.hdf5
# Epoch 85/110
# 630/630 [==============================] - 0s 38us/step - loss: 2.2429 - acc: 0.7349 - val_loss: 1.4261 - val_acc: 0.7286
#
# Epoch 00085: val_loss improved from 1.46588 to 1.42611, saving model to in_for.hdf5
# Epoch 86/110
# 630/630 [==============================] - 0s 42us/step - loss: 2.1815 - acc: 0.7254 - val_loss: 1.3884 - val_acc: 0.7143
#
# Epoch 00086: val_loss improved from 1.42611 to 1.38843, saving model to in_for.hdf5
# Epoch 87/110
# 630/630 [==============================] - 0s 40us/step - loss: 2.1286 - acc: 0.7079 - val_loss: 1.3514 - val_acc: 0.7286
#
# Epoch 00087: val_loss improved from 1.38843 to 1.35138, saving model to in_for.hdf5
# Epoch 88/110
# 630/630 [==============================] - 0s 42us/step - loss: 2.0141 - acc: 0.7286 - val_loss: 1.3187 - val_acc: 0.6857
#
# Epoch 00088: val_loss improved from 1.35138 to 1.31871, saving model to in_for.hdf5
# Epoch 89/110
# 630/630 [==============================] - 0s 36us/step - loss: 1.9549 - acc: 0.7587 - val_loss: 1.2862 - val_acc: 0.7286
#
# Epoch 00089: val_loss improved from 1.31871 to 1.28618, saving model to in_for.hdf5
# Epoch 90/110
# 630/630 [==============================] - 0s 39us/step - loss: 1.9131 - acc: 0.7206 - val_loss: 1.2515 - val_acc: 0.7571
#
# Epoch 00090: val_loss improved from 1.28618 to 1.25154, saving model to in_for.hdf5
# Epoch 91/110
# 630/630 [==============================] - 0s 40us/step - loss: 1.8673 - acc: 0.7000 - val_loss: 1.2178 - val_acc: 0.7714
#
# Epoch 00091: val_loss improved from 1.25154 to 1.21781, saving model to in_for.hdf5
# Epoch 92/110
# 630/630 [==============================] - 0s 42us/step - loss: 1.8072 - acc: 0.7508 - val_loss: 1.1909 - val_acc: 0.7286
#
# Epoch 00092: val_loss improved from 1.21781 to 1.19089, saving model to in_for.hdf5
# Epoch 93/110
# 630/630 [==============================] - 0s 41us/step - loss: 1.7417 - acc: 0.7556 - val_loss: 1.1650 - val_acc: 0.6857
#
# Epoch 00093: val_loss improved from 1.19089 to 1.16502, saving model to in_for.hdf5
# Epoch 94/110
# 630/630 [==============================] - 0s 46us/step - loss: 1.6919 - acc: 0.7413 - val_loss: 1.1351 - val_acc: 0.7429
#
# Epoch 00094: val_loss improved from 1.16502 to 1.13505, saving model to in_for.hdf5
# Epoch 95/110
# 630/630 [==============================] - 0s 41us/step - loss: 1.6289 - acc: 0.7667 - val_loss: 1.1055 - val_acc: 0.7286
#
# Epoch 00095: val_loss improved from 1.13505 to 1.10547, saving model to in_for.hdf5
# Epoch 96/110
# 630/630 [==============================] - 0s 40us/step - loss: 1.5825 - acc: 0.7429 - val_loss: 1.0793 - val_acc: 0.7286
#
# Epoch 00096: val_loss improved from 1.10547 to 1.07927, saving model to in_for.hdf5
# Epoch 97/110
# 630/630 [==============================] - 0s 42us/step - loss: 1.5349 - acc: 0.7762 - val_loss: 1.0528 - val_acc: 0.7571
#
# Epoch 00097: val_loss improved from 1.07927 to 1.05279, saving model to in_for.hdf5
# Epoch 98/110
# 630/630 [==============================] - 0s 36us/step - loss: 1.4906 - acc: 0.7683 - val_loss: 1.0350 - val_acc: 0.7429
#
# Epoch 00098: val_loss improved from 1.05279 to 1.03502, saving model to in_for.hdf5
# Epoch 99/110
# 630/630 [==============================] - 0s 36us/step - loss: 1.4599 - acc: 0.7381 - val_loss: 1.0083 - val_acc: 0.7429
#
# Epoch 00099: val_loss improved from 1.03502 to 1.00828, saving model to in_for.hdf5
# Epoch 100/110
# 630/630 [==============================] - 0s 36us/step - loss: 1.3796 - acc: 0.7746 - val_loss: 0.9869 - val_acc: 0.7286
#
# Epoch 00100: val_loss improved from 1.00828 to 0.98692, saving model to in_for.hdf5
# Epoch 101/110
# 630/630 [==============================] - 0s 38us/step - loss: 1.3497 - acc: 0.7889 - val_loss: 0.9600 - val_acc: 0.7143
#
# Epoch 00101: val_loss improved from 0.98692 to 0.95995, saving model to in_for.hdf5
# Epoch 102/110
# 630/630 [==============================] - 0s 37us/step - loss: 1.3301 - acc: 0.7603 - val_loss: 0.9367 - val_acc: 0.7286
#
# Epoch 00102: val_loss improved from 0.95995 to 0.93672, saving model to in_for.hdf5
# Epoch 103/110
# 630/630 [==============================] - 0s 39us/step - loss: 1.2767 - acc: 0.7810 - val_loss: 0.9201 - val_acc: 0.7571
#
# Epoch 00103: val_loss improved from 0.93672 to 0.92005, saving model to in_for.hdf5
# Epoch 104/110
# 630/630 [==============================] - 0s 41us/step - loss: 1.2314 - acc: 0.7667 - val_loss: 0.8996 - val_acc: 0.7286
#
# Epoch 00104: val_loss improved from 0.92005 to 0.89962, saving model to in_for.hdf5
# Epoch 105/110
# 630/630 [==============================] - 0s 35us/step - loss: 1.1947 - acc: 0.7873 - val_loss: 0.8786 - val_acc: 0.7286
#
# Epoch 00105: val_loss improved from 0.89962 to 0.87864, saving model to in_for.hdf5
# Epoch 106/110
# 630/630 [==============================] - 0s 36us/step - loss: 1.1641 - acc: 0.7825 - val_loss: 0.8590 - val_acc: 0.7571
#
# Epoch 00106: val_loss improved from 0.87864 to 0.85898, saving model to in_for.hdf5
# Epoch 107/110
# 630/630 [==============================] - 0s 35us/step - loss: 1.1252 - acc: 0.7825 - val_loss: 0.8411 - val_acc: 0.7429
#
# Epoch 00107: val_loss improved from 0.85898 to 0.84112, saving model to in_for.hdf5
# Epoch 108/110
# 630/630 [==============================] - 0s 35us/step - loss: 1.1139 - acc: 0.7683 - val_loss: 0.8234 - val_acc: 0.7286
#
# Epoch 00108: val_loss improved from 0.84112 to 0.82338, saving model to in_for.hdf5
# Epoch 109/110
# 630/630 [==============================] - 0s 36us/step - loss: 1.0521 - acc: 0.8016 - val_loss: 0.8072 - val_acc: 0.7429
#
# Epoch 00109: val_loss improved from 0.82338 to 0.80717, saving model to in_for.hdf5
# Epoch 110/110
# 630/630 [==============================] - 0s 39us/step - loss: 1.0228 - acc: 0.8159 - val_loss: 0.7766 - val_acc: 0.7571
#
# Epoch 00110: val_loss improved from 0.80717 to 0.77662, saving model to in_for.hdf5

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
pred = model.predict(np.array(X_test)) 
original = Y_test 
predicted = pred  
plt.figure(figsize=(40,10))
plt.plot(original, color='black', label = 'Original data') 
plt.plot(predicted, color='blue', label = 'Predicted data') 
plt.legend(loc='best') 
plt.title('Actual and predicted') 
plt.show()
