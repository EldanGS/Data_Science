# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
sns.despine()

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import merge
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.layers.advanced_activations import *
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D
from keras.layers.recurrent import LSTM, GRU
from keras import regularizers

import theano
theano.config.compute_test_value = "ignore"
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('ts.csv')
data.head()
# Out:
#        DATE      IN_FOR     OUT_FOR      IN_KZT     OUT_KZT
# 0  1/1/2016         0.0    122953.0   1899647.0   1584705.0
# 1  1/2/2016      2942.0    115059.0   2706416.0   2315761.0
# 2  1/3/2016       263.0    147905.0   3548855.0   2971268.0
# 3  1/4/2016  13533594.0   9363025.0  23528654.0  11716898.0
# 4  1/5/2016  36769881.0  32769452.0  37289979.0  22565273.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 5 columns):
# DATE       731 non-null object
# IN_FOR     731 non-null float64
# OUT_FOR    731 non-null float64
# IN_KZT     731 non-null float64
# OUT_KZT    731 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 28.6+ KB

# %%
def shuffle_in_unison(a, b):
    # courtsey http://stackoverflow.com/users/190280/josh-bleecher-snyder
    assert len(a) == len(b)
    shuffled_a = np.empty(a.shape, dtype=a.dtype)
    shuffled_b = np.empty(b.shape, dtype=b.dtype)
    permutation = np.random.permutation(len(a))
    for old_index, new_index in enumerate(permutation):
        shuffled_a[new_index] = a[old_index]
        shuffled_b[new_index] = b[old_index]
    return shuffled_a, shuffled_b
 
def create_Xt_Yt(X, y, percentage=0.9):
    p = int(len(X) * percentage)
    X_train = X[0:p]
    Y_train = y[0:p]
     
    X_train, Y_train = shuffle_in_unison(X_train, Y_train)
 
    X_test = X[p:]
    Y_test = y[p:]

    return X_train, X_test, Y_train, Y_test

# %%
data0 = data[::-1]
data1 = data0.ix[:, 'OUT_FOR'].tolist()

# Uncomment below to use price change time series
# data1 = data0.ix[:, 'IN_FOR'].pct_change().dropna().tolist()

plt.plot(data1)
plt.show()

WINDOW = 30
EMB_SIZE = 1
STEP = 1
FORECAST = 5

# Straightforward way for creating time windows
X, Y = [], []
for i in range(0, len(data1), STEP): 
    try:
        x_i = data1[i:i+WINDOW]
        y_i = data1[i+WINDOW+FORECAST]  

        last_close = x_i[WINDOW-1]
        next_close = y_i

        if last_close < next_close:
            y_i = [1, 0]
        else:
            y_i = [0, 1] 

    except Exception as e:
        print(e)
        break

    X.append(x_i)
    Y.append(y_i)

X = [(np.array(x) - np.mean(x)) / np.std(x) for x in X] # comment it to remove normalization
X, Y = np.array(X), np.array(Y)

X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# list index out of range

# %%
model = Sequential()
model.add(Dense(64, input_dim=30,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())

model.add(Dropout(0.35))
model.add(Dense(16,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dense(2))
model.add(Activation('linear'))

opt = Nadam(lr=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=25, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint(filepath="out_for.hdf5", verbose=1, save_best_only=True)
model.compile(optimizer=opt, 
              loss='mean_squared_error',
              metrics=['acc'])

# %%
history = model.fit(X_train, Y_train, 
          nb_epoch = 110, 
          batch_size = 128, 
          verbose=1, 
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr, checkpointer],
          shuffle=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   import sys
# Train on 626 samples, validate on 70 samples
# Epoch 1/110
# 626/626 [==============================] - 1s 2ms/step - loss: 79.3067 - acc: 0.5208 - val_loss: 37.6970 - val_acc: 0.5571
#
# Epoch 00001: val_loss improved from inf to 37.69695, saving model to out_for.hdf5
# Epoch 2/110
# 626/626 [==============================] - 0s 39us/step - loss: 72.0324 - acc: 0.5096 - val_loss: 34.9483 - val_acc: 0.5571
#
# Epoch 00002: val_loss improved from 37.69695 to 34.94829, saving model to out_for.hdf5
# Epoch 3/110
# 626/626 [==============================] - 0s 44us/step - loss: 65.7082 - acc: 0.4952 - val_loss: 32.3839 - val_acc: 0.5571
#
# Epoch 00003: val_loss improved from 34.94829 to 32.38393, saving model to out_for.hdf5
# Epoch 4/110
# 626/626 [==============================] - 0s 36us/step - loss: 60.4232 - acc: 0.5415 - val_loss: 30.0365 - val_acc: 0.5429
#
# Epoch 00004: val_loss improved from 32.38393 to 30.03653, saving model to out_for.hdf5
# Epoch 5/110
# 626/626 [==============================] - 0s 39us/step - loss: 55.4827 - acc: 0.5272 - val_loss: 27.9120 - val_acc: 0.5857
#
# Epoch 00005: val_loss improved from 30.03653 to 27.91204, saving model to out_for.hdf5
# Epoch 6/110
# 626/626 [==============================] - 0s 37us/step - loss: 51.2681 - acc: 0.5527 - val_loss: 26.0008 - val_acc: 0.5571
#
# Epoch 00006: val_loss improved from 27.91204 to 26.00080, saving model to out_for.hdf5
# Epoch 7/110
# 626/626 [==============================] - 0s 48us/step - loss: 47.1616 - acc: 0.5463 - val_loss: 24.2657 - val_acc: 0.5714
#
# Epoch 00007: val_loss improved from 26.00080 to 24.26575, saving model to out_for.hdf5
# Epoch 8/110
# 626/626 [==============================] - 0s 69us/step - loss: 43.3999 - acc: 0.5256 - val_loss: 22.7100 - val_acc: 0.5714
#
# Epoch 00008: val_loss improved from 24.26575 to 22.70996, saving model to out_for.hdf5
# Epoch 9/110
# 626/626 [==============================] - 0s 61us/step - loss: 40.3740 - acc: 0.5176 - val_loss: 21.3133 - val_acc: 0.5571
#
# Epoch 00009: val_loss improved from 22.70996 to 21.31330, saving model to out_for.hdf5
# Epoch 10/110
# 626/626 [==============================] - 0s 66us/step - loss: 37.8974 - acc: 0.5351 - val_loss: 20.0445 - val_acc: 0.5571
#
# Epoch 00010: val_loss improved from 21.31330 to 20.04450, saving model to out_for.hdf5
# Epoch 11/110
# 626/626 [==============================] - 0s 55us/step - loss: 35.2260 - acc: 0.5288 - val_loss: 18.8951 - val_acc: 0.5429
#
# Epoch 00011: val_loss improved from 20.04450 to 18.89508, saving model to out_for.hdf5
# Epoch 12/110
# 626/626 [==============================] - 0s 37us/step - loss: 33.0230 - acc: 0.5495 - val_loss: 17.8270 - val_acc: 0.5429
#
# Epoch 00012: val_loss improved from 18.89508 to 17.82702, saving model to out_for.hdf5
# Epoch 13/110
# 626/626 [==============================] - 0s 38us/step - loss: 30.9408 - acc: 0.5351 - val_loss: 16.8567 - val_acc: 0.5429
#
# Epoch 00013: val_loss improved from 17.82702 to 16.85668, saving model to out_for.hdf5
# Epoch 14/110
# 626/626 [==============================] - 0s 39us/step - loss: 29.2300 - acc: 0.5335 - val_loss: 15.9689 - val_acc: 0.5571
#
# Epoch 00014: val_loss improved from 16.85668 to 15.96889, saving model to out_for.hdf5
# Epoch 15/110
# 626/626 [==============================] - 0s 62us/step - loss: 27.2999 - acc: 0.5383 - val_loss: 15.1581 - val_acc: 0.5571
#
# Epoch 00015: val_loss improved from 15.96889 to 15.15812, saving model to out_for.hdf5
# Epoch 16/110
# 626/626 [==============================] - 0s 48us/step - loss: 25.8642 - acc: 0.5639 - val_loss: 14.4077 - val_acc: 0.5143
#
# Epoch 00016: val_loss improved from 15.15812 to 14.40775, saving model to out_for.hdf5
# Epoch 17/110
# 626/626 [==============================] - 0s 45us/step - loss: 24.4007 - acc: 0.5559 - val_loss: 13.7231 - val_acc: 0.5000
#
# Epoch 00017: val_loss improved from 14.40775 to 13.72307, saving model to out_for.hdf5
# Epoch 18/110
# 626/626 [==============================] - 0s 43us/step - loss: 23.4003 - acc: 0.5431 - val_loss: 13.0835 - val_acc: 0.5143
#
# Epoch 00018: val_loss improved from 13.72307 to 13.08353, saving model to out_for.hdf5
# Epoch 19/110
# 626/626 [==============================] - 0s 39us/step - loss: 22.1751 - acc: 0.5224 - val_loss: 12.4805 - val_acc: 0.5571
#
# Epoch 00019: val_loss improved from 13.08353 to 12.48046, saving model to out_for.hdf5
# Epoch 20/110
# 626/626 [==============================] - 0s 76us/step - loss: 21.1229 - acc: 0.5831 - val_loss: 11.9252 - val_acc: 0.5143
#
# Epoch 00020: val_loss improved from 12.48046 to 11.92523, saving model to out_for.hdf5
# Epoch 21/110
# 626/626 [==============================] - 0s 30us/step - loss: 19.8392 - acc: 0.5591 - val_loss: 11.4132 - val_acc: 0.5000
#
# Epoch 00021: val_loss improved from 11.92523 to 11.41321, saving model to out_for.hdf5
# Epoch 22/110
# 626/626 [==============================] - 0s 103us/step - loss: 18.9888 - acc: 0.5911 - val_loss: 10.9300 - val_acc: 0.5286
#
# Epoch 00022: val_loss improved from 11.41321 to 10.93001, saving model to out_for.hdf5
# Epoch 23/110
# 626/626 [==============================] - 0s 64us/step - loss: 18.2019 - acc: 0.5639 - val_loss: 10.4824 - val_acc: 0.5429
#
# Epoch 00023: val_loss improved from 10.93001 to 10.48240, saving model to out_for.hdf5
# Epoch 24/110
# 626/626 [==============================] - 0s 69us/step - loss: 17.3008 - acc: 0.5639 - val_loss: 10.0615 - val_acc: 0.5429
#
# Epoch 00024: val_loss improved from 10.48240 to 10.06147, saving model to out_for.hdf5
# Epoch 25/110
# 626/626 [==============================] - 0s 40us/step - loss: 16.6913 - acc: 0.5671 - val_loss: 9.6731 - val_acc: 0.5429
#
# Epoch 00025: val_loss improved from 10.06147 to 9.67305, saving model to out_for.hdf5
# Epoch 26/110
# 626/626 [==============================] - 0s 37us/step - loss: 15.8823 - acc: 0.5847 - val_loss: 9.3023 - val_acc: 0.5714
#
# Epoch 00026: val_loss improved from 9.67305 to 9.30229, saving model to out_for.hdf5
# Epoch 27/110
# 626/626 [==============================] - 0s 32us/step - loss: 15.1818 - acc: 0.5623 - val_loss: 8.9538 - val_acc: 0.5714
#
# Epoch 00027: val_loss improved from 9.30229 to 8.95381, saving model to out_for.hdf5
# Epoch 28/110
# 626/626 [==============================] - 0s 55us/step - loss: 14.6790 - acc: 0.5879 - val_loss: 8.6215 - val_acc: 0.5714
#
# Epoch 00028: val_loss improved from 8.95381 to 8.62148, saving model to out_for.hdf5
# Epoch 29/110
# 626/626 [==============================] - 0s 43us/step - loss: 14.0047 - acc: 0.5783 - val_loss: 8.3086 - val_acc: 0.5857
#
# Epoch 00029: val_loss improved from 8.62148 to 8.30859, saving model to out_for.hdf5
# Epoch 30/110
# 626/626 [==============================] - 0s 39us/step - loss: 13.6307 - acc: 0.5927 - val_loss: 8.0143 - val_acc: 0.5571
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00030: val_loss improved from 8.30859 to 8.01426, saving model to out_for.hdf5
# Epoch 31/110
# 626/626 [==============================] - 0s 46us/step - loss: 13.0489 - acc: 0.5895 - val_loss: 7.7592 - val_acc: 0.5429
#
# Epoch 00031: val_loss improved from 8.01426 to 7.75922, saving model to out_for.hdf5
# Epoch 32/110
# 626/626 [==============================] - 0s 44us/step - loss: 12.6531 - acc: 0.5815 - val_loss: 7.5150 - val_acc: 0.5429
#
# Epoch 00032: val_loss improved from 7.75922 to 7.51501, saving model to out_for.hdf5
# Epoch 33/110
# 626/626 [==============================] - 0s 50us/step - loss: 12.1577 - acc: 0.6326 - val_loss: 7.2816 - val_acc: 0.5714
#
# Epoch 00033: val_loss improved from 7.51501 to 7.28161, saving model to out_for.hdf5
# Epoch 34/110
# 626/626 [==============================] - 0s 45us/step - loss: 11.8219 - acc: 0.6118 - val_loss: 7.0557 - val_acc: 0.5857
#
# Epoch 00034: val_loss improved from 7.28161 to 7.05574, saving model to out_for.hdf5
# Epoch 35/110
# 626/626 [==============================] - 0s 34us/step - loss: 11.4549 - acc: 0.6278 - val_loss: 6.8410 - val_acc: 0.6000
#
# Epoch 00035: val_loss improved from 7.05574 to 6.84096, saving model to out_for.hdf5
# Epoch 36/110
# 626/626 [==============================] - 0s 40us/step - loss: 11.1128 - acc: 0.5974 - val_loss: 6.6318 - val_acc: 0.6143
#
# Epoch 00036: val_loss improved from 6.84096 to 6.63179, saving model to out_for.hdf5
# Epoch 37/110
# 626/626 [==============================] - 0s 35us/step - loss: 10.8205 - acc: 0.5990 - val_loss: 6.4331 - val_acc: 0.6286
#
# Epoch 00037: val_loss improved from 6.63179 to 6.43310, saving model to out_for.hdf5
# Epoch 38/110
# 626/626 [==============================] - 0s 28us/step - loss: 10.3847 - acc: 0.5958 - val_loss: 6.2399 - val_acc: 0.6429
#
# Epoch 00038: val_loss improved from 6.43310 to 6.23995, saving model to out_for.hdf5
# Epoch 39/110
# 626/626 [==============================] - 0s 40us/step - loss: 10.1396 - acc: 0.6022 - val_loss: 6.0554 - val_acc: 0.6571
#
# Epoch 00039: val_loss improved from 6.23995 to 6.05535, saving model to out_for.hdf5
# Epoch 40/110
# 626/626 [==============================] - 0s 37us/step - loss: 9.8012 - acc: 0.6054 - val_loss: 5.8741 - val_acc: 0.6714
#
# Epoch 00040: val_loss improved from 6.05535 to 5.87409, saving model to out_for.hdf5
# Epoch 41/110
# 626/626 [==============================] - 0s 28us/step - loss: 9.5044 - acc: 0.6390 - val_loss: 5.7042 - val_acc: 0.6714
#
# Epoch 00041: val_loss improved from 5.87409 to 5.70422, saving model to out_for.hdf5
# Epoch 42/110
# 626/626 [==============================] - 0s 29us/step - loss: 9.2267 - acc: 0.6118 - val_loss: 5.5411 - val_acc: 0.6714
#
# Epoch 00042: val_loss improved from 5.70422 to 5.54115, saving model to out_for.hdf5
# Epoch 43/110
# 626/626 [==============================] - 0s 31us/step - loss: 8.9032 - acc: 0.6390 - val_loss: 5.3803 - val_acc: 0.6857
#
# Epoch 00043: val_loss improved from 5.54115 to 5.38029, saving model to out_for.hdf5
# Epoch 44/110
# 626/626 [==============================] - 0s 29us/step - loss: 8.6796 - acc: 0.6006 - val_loss: 5.2221 - val_acc: 0.6857
#
# Epoch 00044: val_loss improved from 5.38029 to 5.22214, saving model to out_for.hdf5
# Epoch 45/110
# 626/626 [==============================] - 0s 47us/step - loss: 8.4484 - acc: 0.6246 - val_loss: 5.0703 - val_acc: 0.7000
#
# Epoch 00045: val_loss improved from 5.22214 to 5.07030, saving model to out_for.hdf5
# Epoch 46/110
# 626/626 [==============================] - 0s 31us/step - loss: 8.1848 - acc: 0.6502 - val_loss: 4.9242 - val_acc: 0.6857
#
# Epoch 00046: val_loss improved from 5.07030 to 4.92415, saving model to out_for.hdf5
# Epoch 47/110
# 626/626 [==============================] - 0s 31us/step - loss: 8.0006 - acc: 0.6390 - val_loss: 4.7824 - val_acc: 0.7000
#
# Epoch 00047: val_loss improved from 4.92415 to 4.78244, saving model to out_for.hdf5
# Epoch 48/110
# 626/626 [==============================] - 0s 34us/step - loss: 7.7689 - acc: 0.6502 - val_loss: 4.6455 - val_acc: 0.6857
#
# Epoch 00048: val_loss improved from 4.78244 to 4.64552, saving model to out_for.hdf5
# Epoch 49/110
# 626/626 [==============================] - 0s 30us/step - loss: 7.5787 - acc: 0.6422 - val_loss: 4.5127 - val_acc: 0.6857
#
# Epoch 00049: val_loss improved from 4.64552 to 4.51269, saving model to out_for.hdf5
# Epoch 50/110
# 626/626 [==============================] - 0s 36us/step - loss: 7.3038 - acc: 0.6374 - val_loss: 4.3831 - val_acc: 0.7000
#
# Epoch 00050: val_loss improved from 4.51269 to 4.38307, saving model to out_for.hdf5
# Epoch 51/110
# 626/626 [==============================] - 0s 35us/step - loss: 7.0802 - acc: 0.6550 - val_loss: 4.2578 - val_acc: 0.6714
#
# Epoch 00051: val_loss improved from 4.38307 to 4.25782, saving model to out_for.hdf5
# Epoch 52/110
# 626/626 [==============================] - 0s 38us/step - loss: 6.8775 - acc: 0.6214 - val_loss: 4.1385 - val_acc: 0.6714
#
# Epoch 00052: val_loss improved from 4.25782 to 4.13850, saving model to out_for.hdf5
# Epoch 53/110
# 626/626 [==============================] - 0s 34us/step - loss: 6.6783 - acc: 0.6326 - val_loss: 4.0205 - val_acc: 0.6714
#
# Epoch 00053: val_loss improved from 4.13850 to 4.02050, saving model to out_for.hdf5
# Epoch 54/110
# 626/626 [==============================] - 0s 35us/step - loss: 6.4968 - acc: 0.6677 - val_loss: 3.9104 - val_acc: 0.6571
#
# Epoch 00054: val_loss improved from 4.02050 to 3.91044, saving model to out_for.hdf5
# Epoch 55/110
# 626/626 [==============================] - 0s 36us/step - loss: 6.3207 - acc: 0.6534 - val_loss: 3.8015 - val_acc: 0.6429
#
# Epoch 00055: val_loss improved from 3.91044 to 3.80149, saving model to out_for.hdf5
# Epoch 56/110
# 626/626 [==============================] - 0s 42us/step - loss: 6.1671 - acc: 0.6534 - val_loss: 3.6943 - val_acc: 0.6571
#
# Epoch 00056: val_loss improved from 3.80149 to 3.69433, saving model to out_for.hdf5
# Epoch 57/110
# 626/626 [==============================] - 0s 32us/step - loss: 6.0256 - acc: 0.6597 - val_loss: 3.5937 - val_acc: 0.6571
#
# Epoch 00057: val_loss improved from 3.69433 to 3.59370, saving model to out_for.hdf5
# Epoch 58/110
# 626/626 [==============================] - 0s 34us/step - loss: 5.8770 - acc: 0.6885 - val_loss: 3.4946 - val_acc: 0.6429
#
# Epoch 00058: val_loss improved from 3.59370 to 3.49458, saving model to out_for.hdf5
# Epoch 59/110
# 626/626 [==============================] - 0s 34us/step - loss: 5.6212 - acc: 0.6853 - val_loss: 3.3978 - val_acc: 0.6429
#
# Epoch 00059: val_loss improved from 3.49458 to 3.39782, saving model to out_for.hdf5
# Epoch 60/110
# 626/626 [==============================] - 0s 40us/step - loss: 5.4962 - acc: 0.6422 - val_loss: 3.3029 - val_acc: 0.6857
#
# Epoch 00060: val_loss improved from 3.39782 to 3.30291, saving model to out_for.hdf5
# Epoch 61/110
# 626/626 [==============================] - ETA: 0s - loss: 5.3440 - acc: 0.734 - 0s 31us/step - loss: 5.3723 - acc: 0.6454 - val_loss: 3.2098 - val_acc: 0.6857
#
# Epoch 00061: val_loss improved from 3.30291 to 3.20982, saving model to out_for.hdf5
# Epoch 62/110
# 626/626 [==============================] - 0s 33us/step - loss: 5.2596 - acc: 0.6581 - val_loss: 3.1212 - val_acc: 0.6714
#
# Epoch 00062: val_loss improved from 3.20982 to 3.12123, saving model to out_for.hdf5
# Epoch 63/110
# 626/626 [==============================] - 0s 30us/step - loss: 5.1010 - acc: 0.6917 - val_loss: 3.0370 - val_acc: 0.6714
#
# Epoch 00063: val_loss improved from 3.12123 to 3.03702, saving model to out_for.hdf5
# Epoch 64/110
# 626/626 [==============================] - 0s 29us/step - loss: 4.9317 - acc: 0.6917 - val_loss: 2.9537 - val_acc: 0.6857
#
# Epoch 00064: val_loss improved from 3.03702 to 2.95365, saving model to out_for.hdf5
# Epoch 65/110
# 626/626 [==============================] - 0s 29us/step - loss: 4.8196 - acc: 0.6901 - val_loss: 2.8745 - val_acc: 0.6714
#
# Epoch 00065: val_loss improved from 2.95365 to 2.87445, saving model to out_for.hdf5
# Epoch 66/110
# 626/626 [==============================] - 0s 30us/step - loss: 4.6408 - acc: 0.7045 - val_loss: 2.7963 - val_acc: 0.6714
#
# Epoch 00066: val_loss improved from 2.87445 to 2.79631, saving model to out_for.hdf5
# Epoch 67/110
# 626/626 [==============================] - 0s 29us/step - loss: 4.5654 - acc: 0.6677 - val_loss: 2.7222 - val_acc: 0.6714
#
# Epoch 00067: val_loss improved from 2.79631 to 2.72218, saving model to out_for.hdf5
# Epoch 68/110
# 626/626 [==============================] - 0s 31us/step - loss: 4.4109 - acc: 0.6965 - val_loss: 2.6497 - val_acc: 0.6714
#
# Epoch 00068: val_loss improved from 2.72218 to 2.64970, saving model to out_for.hdf5
# Epoch 69/110
# 626/626 [==============================] - 0s 29us/step - loss: 4.3187 - acc: 0.6981 - val_loss: 2.5786 - val_acc: 0.6857
#
# Epoch 00069: val_loss improved from 2.64970 to 2.57865, saving model to out_for.hdf5
# Epoch 70/110
# 626/626 [==============================] - 0s 29us/step - loss: 4.2041 - acc: 0.7029 - val_loss: 2.5093 - val_acc: 0.6714
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 00070: val_loss improved from 2.57865 to 2.50927, saving model to out_for.hdf5
# Epoch 71/110
# 626/626 [==============================] - 0s 31us/step - loss: 4.0560 - acc: 0.7109 - val_loss: 2.4477 - val_acc: 0.6714
#
# Epoch 00071: val_loss improved from 2.50927 to 2.44773, saving model to out_for.hdf5
# Epoch 72/110
# 626/626 [==============================] - 0s 31us/step - loss: 4.0102 - acc: 0.6789 - val_loss: 2.3893 - val_acc: 0.6857
#
# Epoch 00072: val_loss improved from 2.44773 to 2.38934, saving model to out_for.hdf5
# Epoch 73/110
# 626/626 [==============================] - 0s 31us/step - loss: 3.9229 - acc: 0.7077 - val_loss: 2.3328 - val_acc: 0.6714
# Epoch 00073: val_loss improved from 2.38934 to 2.33280, saving model to out_for.hdf5
# Epoch 74/110
# 626/626 [==============================] - 0s 30us/step - loss: 3.8072 - acc: 0.7045 - val_loss: 2.2762 - val_acc: 0.6857
#
# Epoch 00074: val_loss improved from 2.33280 to 2.27619, saving model to out_for.hdf5
# Epoch 75/110
# 626/626 [==============================] - 0s 29us/step - loss: 3.7254 - acc: 0.7141 - val_loss: 2.2227 - val_acc: 0.7000
#
# Epoch 00075: val_loss improved from 2.27619 to 2.22265, saving model to out_for.hdf5
# Epoch 76/110
# 626/626 [==============================] - 0s 30us/step - loss: 3.6334 - acc: 0.7093 - val_loss: 2.1700 - val_acc: 0.6857
#
# Epoch 00076: val_loss improved from 2.22265 to 2.17003, saving model to out_for.hdf5
# Epoch 77/110
# 626/626 [==============================] - 0s 30us/step - loss: 3.5547 - acc: 0.6997 - val_loss: 2.1181 - val_acc: 0.6857
#
# Epoch 00077: val_loss improved from 2.17003 to 2.11813, saving model to out_for.hdf5
# Epoch 78/110
# 626/626 [==============================] - 0s 29us/step - loss: 3.4757 - acc: 0.7157 - val_loss: 2.0690 - val_acc: 0.6857
#
# Epoch 00078: val_loss improved from 2.11813 to 2.06903, saving model to out_for.hdf5
# Epoch 79/110
# 626/626 [==============================] - 0s 37us/step - loss: 3.3852 - acc: 0.7061 - val_loss: 2.0191 - val_acc: 0.7286
#
# Epoch 00079: val_loss improved from 2.06903 to 2.01906, saving model to out_for.hdf5
# Epoch 80/110
# 128/626 [=====>........................] - ETA: 0s - loss: 3.4465 - acc: 0.6797

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
