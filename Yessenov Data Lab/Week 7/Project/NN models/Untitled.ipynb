# %%
import pandas as pd

# %%
df = pd.read_csv('timeseries2.csv')
df.head()
# Out:
#        DATE   INBOUND_FOR    OUTBOUND_FOR    NET_FOR    INBOUND_KZT   \
# 0  1/1/2016            0.0        122953.0  -122953.0      1899647.0
# 1  1/2/2016         2942.0        115059.0  -112117.0      2706416.0
# 2  1/3/2016          263.0        147905.0  -147642.0      3548855.0
# 3  1/4/2016     13533594.0       9363025.0  4170569.0     23528654.0
# 4  1/5/2016     36769881.0      32769452.0  4000429.0     37289979.0
#
#     OUTBOUND_KZT     NET_KZT    NET_TOTAL      USD     EUR   ...     \
# 0       1584705.0    314942.0     191989.0  340.01  371.46   ...
# 1       2315761.0    390655.0     278538.0  340.01  371.46   ...
# 2       2971268.0    577587.0     429945.0  340.01  371.46   ...
# 3      11716898.0  11811756.0   15982325.0  340.01  371.46   ...
# 4      22565273.0  14724706.0   18725135.0  340.01  371.46   ...
#
#    DELTA_IN_FOR  DELTA_OUT_FOR  DELTA_NET_FOR  DELTA_IN_KZT  DELTA_OUT_KZT  \
# 0        0.0000         0.0000         0.0000        0.0000         0.0000
# ...

# %%
df.columns
# Out:
# Index([u'DATE', u' INBOUND_FOR ', u' OUTBOUND_FOR ', u' NET_FOR ',
#        u' INBOUND_KZT ', u' OUTBOUND_KZT ', u' NET_KZT ', u' NET_TOTAL ',
#        u'USD', u'EUR', u'DELTA_NET_USD', u'DELTA_NET_EUR', u'DELTA_IN_FOR',
#        u'DELTA_OUT_FOR', u'DELTA_NET_FOR', u'DELTA_IN_KZT', u'DELTA_OUT_KZT',
#        u'DELTA_NET_KZT', u'DELTA_NET_TOTAL', u'CALENDAR', u'RATE_FOR',
#        u'RATE_KZT'],
#       dtype='object')

# %%
delta_kzt = df['DELTA_NET_USD']

# %%
delta_kzt.to_csv('delta_kzt.csv')
