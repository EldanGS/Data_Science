# %% [markdown]
# ## Add libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import optimize 

from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import ElasticNet
from catboost import CatBoostRegressor
import xgboost as xgb


from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

from pandas_profiling import ProfileReport
# %matplotlib inline

# %% [markdown]
# ### Load train dataset

# %%
# air_df = pd.read_excel("Air Quality Data Set/AirQualityUCI.xlsx")
air_df = pd.read_csv("train.csv")
air_df.head(5).T
# Out:
#                                 0                    1                    2  \
# Datetime      2004-03-10 18:00:00  2004-03-10 19:00:00  2004-03-10 20:00:00
# CO(GT)                        2.6                    2                  2.2
# PT08.S1(CO)                  1360              1292.25                 1402
# NMHC(GT)                      150                  112                   88
# C6H6(GT)                  11.8817              9.39716              8.99782
# NOx(GT)                       166                  103                  131
# PT08.S3(NOx)              1056.25              1173.75                 1140
# NO2(GT)                       113                   92                  114
# PT08.S4(NO2)                 1692              1558.75               1554.5
# PT08.S5(O3)                1267.5               972.25                 1074
# T                            13.6                 13.3                 11.9
# RH                         48.875                 47.7               53.975
# AH                       0.757754             0.725487             0.750239
#
#                                 3                    4
# Datetime      2004-03-10 21:00:00  2004-03-10 22:00:00
# CO(GT)                        2.2                  1.6
# PT08.S1(CO)                1375.5              1272.25
# NMHC(GT)                       80                   51
# C6H6(GT)                   9.2288              6.51822
# NOx(GT)                       172                  131
# PT08.S3(NOx)                 1092                 1205
# NO2(GT)                       122                  116
# PT08.S4(NO2)              1583.75                 1490
# PT08.S5(O3)               1203.25                 1110
# T                              11                11.15
# RH                             60               59.575
# AH                       0.786713             0.788794

# %%
air_df.shape
# Out:
# (6218, 13)

# %% [markdown]
# #### Remove rows where is elements has -200 ~ NaN

# %%
air_df = air_df[air_df["C6H6(GT)"] != -200]

# %% [markdown]
# #### Get info about series with -200

# %%
air_df[air_df == -200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 13 columns):
# Datetime        0 non-null object
# CO(GT)          1447 non-null float64
# PT08.S1(CO)     0 non-null float64
# NMHC(GT)        5331 non-null float64
# C6H6(GT)        0 non-null float64
# NOx(GT)         1406 non-null float64
# PT08.S3(NOx)    0 non-null float64
# NO2(GT)         1409 non-null float64
# PT08.S4(NO2)    0 non-null float64
# PT08.S5(O3)     0 non-null float64
# T               0 non-null float64
# RH              0 non-null float64
# AH              0 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 680.1+ KB

# %% [markdown]
# #### Remove highest frequency sets with -200

# %%
air_df.drop("NMHC(GT)", axis = 1, inplace = True)
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 12 columns):
# Datetime        6218 non-null object
# CO(GT)          6218 non-null float64
# PT08.S1(CO)     6218 non-null float64
# C6H6(GT)        6218 non-null float64
# NOx(GT)         6218 non-null int64
# PT08.S3(NOx)    6218 non-null float64
# NO2(GT)         6218 non-null int64
# PT08.S4(NO2)    6218 non-null float64
# PT08.S5(O3)     6218 non-null float64
# T               6218 non-null float64
# RH              6218 non-null float64
# AH              6218 non-null float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 631.5+ KB

# %% [markdown]
# ## Preprocessing
# #### Three sets with NaN values

# %%
data_cogt_neg = ["NOx(GT)", "NO2(GT)", "C6H6(GT)"]
data_noxgt_neg = ["CO(GT)", "NO2(GT)", "C6H6(GT)"]
data_no2gt_neg = ["NOx(GT)", "CO(GT)", "C6H6(GT)"]

# %%
cogt_df = air_df.drop(data_cogt_neg, axis = 1)
noxgt_df = air_df.drop(data_noxgt_neg, axis = 1)
no2gt_df = air_df.drop(data_no2gt_neg, axis = 1)

# %%
cogt_df.reset_index(inplace = True)
noxgt_df.reset_index(inplace = True)
no2gt_df.reset_index(inplace = True)

# %% [markdown]
# ### Preprocessing CO(GT) series

# %%
x_test = cogt_df[cogt_df["CO(GT)"] == -200]
pos = list(x_test.index.values)
cogt_df.drop(cogt_df.index[pos], axis = 0, inplace = True)

x_train = cogt_df.drop("Datetime", axis = 1)
x_test = x_test.drop(["Datetime", "CO(GT)"], axis = 1)

y_train = x_train.pop("CO(GT)")

x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %%
x_test.head()
# Out:
#        index  PT08.S1(CO)  PT08.S3(NOx)  PT08.S4(NO2)  PT08.S5(O3)         T  \
# 10 -2.104603    -0.271194      3.962927     -1.415355    -1.462411 -1.711584
# 34 -2.089324    -1.143585      4.272779     -1.649089    -1.637446 -2.260971
# 39 -2.086141     2.314476     -0.361625      1.779941     1.802520 -1.829063
# 58 -2.074044     0.387946      1.141314     -0.617690     0.098612 -2.136581
# 82 -2.058765     0.303130      1.133078     -0.469287     0.267216 -1.431708
#
#           RH        AH
# 10  0.655672 -1.582340
# 34  0.977237 -1.953135
# 39  0.402273 -1.857767
# 58  1.283983 -1.675894
# 82  0.692719 -1.235665

# %% [markdown]
# ### Build predicting model

# %%
rng = np.random.RandomState(1)
# model = Ridge(alpha = 0.0000001, random_state = 10, solver = 'saga')
model = RandomForestRegressor(n_estimators=500, max_features=5, random_state=rng)
# model = GradientBoostingRegressor(n_estimators = 300, max_depth = 7, random_state = 15)
# model = ElasticNet(alpha = 0.2, random_state = 10)
# model = CatBoostRegressor(depth = 7)
# model = xgb.XGBRegressor()
# model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
model.fit(x_train, y_train)

pred = model.predict(x_test)

# %% [markdown]
# ### Switch NaN values to predicted

# %%
ind = 0
for i in pos:
    air_df.loc[i, "CO(GT)"] = pred[ind]
    ind += 1

air_df.head()
# Out:
#               Datetime  CO(GT)  PT08.S1(CO)   C6H6(GT)  NOx(GT)  PT08.S3(NOx)  \
# 0  2004-03-10 18:00:00     2.6      1360.00  11.881723      166       1056.25
# 1  2004-03-10 19:00:00     2.0      1292.25   9.397165      103       1173.75
# 2  2004-03-10 20:00:00     2.2      1402.00   8.997817      131       1140.00
# 3  2004-03-10 21:00:00     2.2      1375.50   9.228796      172       1092.00
# 4  2004-03-10 22:00:00     1.6      1272.25   6.518224      131       1205.00
#
#    NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH        AH
# 0      113       1692.00      1267.50  13.60  48.875001  0.757754
# 1       92       1558.75       972.25  13.30  47.700000  0.725487
# 2      114       1554.50      1074.00  11.90  53.975000  0.750239
# 3      122       1583.75      1203.25  11.00  60.000000  0.786713
# 4      116       1490.00      1110.00  11.15  59.575001  0.788794

# %% [markdown]
# ### Preprocessing NOx(GT) series

# %%
x_test = noxgt_df[noxgt_df["NOx(GT)"] == -200]
pos = list(x_test.index.values)
noxgt_df.drop(noxgt_df.index[pos], axis = 0, inplace = True)

x_train = noxgt_df.drop("Datetime", axis = 1)
x_test = x_test.drop(["Datetime", "NOx(GT)"], axis = 1)

y_train = x_train.pop("NOx(GT)")

x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %% [markdown]
# ### Build predicting model

# %%
rng = np.random.RandomState(1)
# model = Ridge(alpha = 0.0000001, random_state = 10, solver = 'saga')
model = RandomForestRegressor(n_jobs = -1, random_state=rng)
# model = GradientBoostingRegressor(n_estimators = 300, max_depth = 7, random_state = 15)
# model = ElasticNet(alpha = 0.2, random_state = 10)
# model = CatBoostRegressor( depth = 7)
# model = xgb.XGBRegressor()
# model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
model.fit(x_train, y_train)

pred = model.predict(x_test)

# %% [markdown]
# ### Switch NaN(-200) values to predicted

# %%
ind = 0
for i in pos:
    air_df.loc[i, "NOx(GT)"] = pred[ind]
    ind += 1

air_df.head()
# Out:
#               Datetime  CO(GT)  PT08.S1(CO)   C6H6(GT)  NOx(GT)  PT08.S3(NOx)  \
# 0  2004-03-10 18:00:00     2.6      1360.00  11.881723    166.0       1056.25
# 1  2004-03-10 19:00:00     2.0      1292.25   9.397165    103.0       1173.75
# 2  2004-03-10 20:00:00     2.2      1402.00   8.997817    131.0       1140.00
# 3  2004-03-10 21:00:00     2.2      1375.50   9.228796    172.0       1092.00
# 4  2004-03-10 22:00:00     1.6      1272.25   6.518224    131.0       1205.00
#
#    NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH        AH
# 0      113       1692.00      1267.50  13.60  48.875001  0.757754
# 1       92       1558.75       972.25  13.30  47.700000  0.725487
# 2      114       1554.50      1074.00  11.90  53.975000  0.750239
# 3      122       1583.75      1203.25  11.00  60.000000  0.786713
# 4      116       1490.00      1110.00  11.15  59.575001  0.788794

# %% [markdown]
# ### Preprocessing NO2(GT) series

# %%
x_test = no2gt_df[no2gt_df["NO2(GT)"] == -200]
pos = list(x_test.index.values)
no2gt_df.drop(no2gt_df.index[pos], axis = 0, inplace = True)

x_train = no2gt_df.drop("Datetime", axis = 1)
x_test = x_test.drop(["Datetime", "NO2(GT)"], axis = 1)

y_train = x_train.pop("NO2(GT)")

x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %% [markdown]
# ### Build predicting model

# %%
rng = np.random.RandomState(1)
# model = Ridge(alpha = 0.0000001, random_state = 10, solver = 'saga')
model = RandomForestRegressor(n_jobs = -1, random_state=rng)
# model = GradientBoostingRegressor(n_estimators = 300, max_depth = 10, random_state = 10)
# model = ElasticNet(alpha = 0.2, random_state = 10)
# model = CatBoostRegressor(depth = 7)
# model = xgb.XGBRegressor()
# model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
model.fit(x_train, y_train)

pred = model.predict(x_test)

# %% [markdown]
# ### Switch NaN values to predicted

# %%
ind = 0
for i in pos:
    air_df.loc[i, "NO2(GT)"] = pred[ind]
    ind += 1

# %% [markdown]
# ### Checkout dataset to -200

# %%
air_df[air_df == -200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 12 columns):
# Datetime        0 non-null object
# CO(GT)          0 non-null float64
# PT08.S1(CO)     0 non-null float64
# C6H6(GT)        0 non-null float64
# NOx(GT)         0 non-null float64
# PT08.S3(NOx)    0 non-null float64
# NO2(GT)         0 non-null float64
# PT08.S4(NO2)    0 non-null float64
# PT08.S5(O3)     0 non-null float64
# T               0 non-null float64
# RH              0 non-null float64
# AH              0 non-null float64
# dtypes: float64(11), object(1)
# memory usage: 791.5+ KB

# %% [markdown]
# ### Separating dataset

# %%
X = air_df[["CO(GT)", "PT08.S1(CO)","NOx(GT)","PT08.S3(NOx)","NO2(GT)","PT08.S4(NO2)","PT08.S5(O3)","T","RH","AH"]].values
y = air_df[["C6H6(GT)"]].values

# %% [markdown]
# ### Get informationg about models

# %%
tscv = TimeSeriesSplit(n_splits=20)
for train_index, test_index in tscv.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
#     model = GradientBoostingRegressor(n_estimators = 300, max_depth = 3)
#     model = Ridge(alpha=0.000001, random_state=10)
#     model = CatBoostRegressor(depth = 7)
    model = ElasticNet(alpha = 0.41, random_state = 10)
#     model = RandomForestRegressor(n_jobs = -1)
#     model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
#     model = xgb.XGBRegressor()
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    
    print(np.sqrt(mean_squared_error(pred, y_test)))
# Out:
# 1.9567726709193172
# 1.0317066296387565
# 1.5388812732881871
# 1.115024473860909
# 1.0582460432197596
# 2.5923392904149782
# 1.3530518427718374
# 1.2552494426687966
# 1.3560445765701414
# 1.5316503746840755
# 1.2986068389423437
# 0.9268477976755441
# 1.7267207645325584
# 2.2082366233962536
# 1.952563990836469
# 1.83441015608291
# 1.8190960601106854
# 2.2227327177476823
# 3.0317215839299196
# 3.581207677298431

# %% [markdown]
# ### Train final model for predicting

# %%
rng = np.random.RandomState(1)
# final_model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
# final_model = Ridge(alpha=0.000001, random_state=10)
# final_model = DecisionTreeRegressor(max_depth = 4, random_state=rng)
# final_model = LinearRegression(n_jobs = -1)
# final_model = RandomForestRegressor(DecisionTreeRegressor(max_depth=4), n_estimators = 300, n_jobs = -1, random_state=rng)
final_model = ElasticNet(alpha = 0.5, random_state = rng)
final_model.fit(X, y)
# Out:
# ElasticNet(alpha=0.5, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=<mtrand.RandomState object at 0x118d819d8>,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %% [markdown]
# ### Load test dataset

# %%
air_df = pd.read_csv("test.csv")

# %% [markdown]
# ## Repeat all previous steps

# %%
air_df.drop("NMHC(GT)", axis = 1, inplace = True)

# %%
air_df.head()
# Out:
#               Datetime  CO(GT)  PT08.S1(CO)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0  2004-12-01 00:00:00     2.2      1039.25    273.0       1197.75    113.0
# 1  2004-12-01 01:00:00     1.3       885.50    157.0       1900.00     94.0
# 2  2004-12-01 02:00:00     1.2       900.25    117.0       1955.25     76.0
# 3  2004-12-01 03:00:00     0.9       855.50   -200.0       2042.25   -200.0
# 4  2004-12-01 04:00:00  -200.0       856.50    123.0       2061.00     68.0
#
#    PT08.S4(NO2)  PT08.S5(O3)       T         RH        AH
# 0       1251.00       933.00   9.800  79.400002  0.962598
# 1       1106.00       765.50  10.125  75.275000  0.932230
# 2       1126.75       748.75   9.150  80.049999  0.929878
# 3       1100.25       708.50   8.700  82.424999  0.929447
# 4       1082.50       746.00   8.475  81.675001  0.907381

# %%
air_df.reset_index(inplace = True)
data_cogt_neg = ["NOx(GT)", "NO2(GT)"]#, "C6H6(GT)"]
data_noxgt_neg = ["CO(GT)", "NO2(GT)"]#, "C6H6(GT)"]
data_no2gt_neg = ["NOx(GT)", "CO(GT)"]#, "C6H6(GT)"]

# %%
cogt_df = air_df.drop(data_cogt_neg, axis = 1)
noxgt_df = air_df.drop(data_noxgt_neg, axis = 1)
no2gt_df = air_df.drop(data_no2gt_neg, axis = 1)

cogt_df.reset_index(inplace = True)
noxgt_df.reset_index(inplace = True)
no2gt_df.reset_index(inplace = True)

# %%
x_test = cogt_df[cogt_df["CO(GT)"] == -200]
pos = list(x_test.index.values)
cogt_df.drop(cogt_df.index[pos], axis = 0, inplace = True)

x_train = cogt_df.drop("Datetime", axis = 1)
x_test = x_test.drop(["Datetime", "CO(GT)"], axis = 1)

y_train = x_train.pop("CO(GT)")

x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %%
rng = np.random.RandomState(1)
# model = Ridge(alpha = 0.0000001, random_state = 10, solver = 'saga')
model = RandomForestRegressor(n_jobs = -1, random_state=rng)
# model = GradientBoostingRegressor(n_estimators = 300, max_depth = 7, random_state = 15)
# model = ElasticNet(alpha = 0.2, random_state = 10)
# model = CatBoostRegressor(depth = 7)
# model = xgb.XGBRegressor()
# model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
model.fit(x_train, y_train)

pred = model.predict(x_test)

# %%
ind = 0
for i in pos:
    air_df.loc[i, "CO(GT)"] = pred[ind]
    ind += 1

# %%
x_test = no2gt_df[no2gt_df["NO2(GT)"] == -200]
pos = list(x_test.index.values)
no2gt_df.drop(no2gt_df.index[pos], axis = 0, inplace = True)

x_train = no2gt_df.drop("Datetime", axis = 1)
x_test = x_test.drop(["Datetime", "NO2(GT)"], axis = 1)

y_train = x_train.pop("NO2(GT)")

x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %%
rng = np.random.RandomState(1)
# model = Ridge(alpha = 0.0000001, random_state = 10, solver = 'saga')
model = RandomForestRegressor(n_jobs = -1, random_state=rng)
# model = GradientBoostingRegressor(n_estimators = 300, max_depth = 7, random_state = 15)
# model = ElasticNet(alpha = 0.2, random_state = 10)
# model = CatBoostRegressor(depth = 7)
# model = xgb.XGBRegressor()
# model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
model.fit(x_train, y_train)

pred = model.predict(x_test)

# %%
ind = 0
for i in pos:
    air_df.loc[i, "NO2(GT)"] = pred[ind]
    ind += 1

# %%
x_test = noxgt_df[noxgt_df["NOx(GT)"] == -200]
pos = list(x_test.index.values)
noxgt_df.drop(noxgt_df.index[pos], axis = 0, inplace = True)

x_train = noxgt_df.drop("Datetime", axis = 1)
x_test = x_test.drop(["Datetime", "NOx(GT)"], axis = 1)

y_train = x_train.pop("NOx(GT)")

x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %%
rng = np.random.RandomState(1)
# x_test = air_df[["CO(GT)","PT08.S1(CO)", "NOx(GT)","PT08.S3(NOx)","NO2(GT)","PT08.S4(NO2)","PT08.S5(O3)","T","RH","AH"]]
# model = Ridge(alpha = 0.0000001, random_state = 10, solver = 'saga')
model = RandomForestRegressor(n_jobs = -1, random_state=rng)
# model = GradientBoostingRegressor(n_estimators = 300, max_depth = 7, random_state = 15)
# model = ElasticNet(alpha = 0.2, random_state = 10)
# model = CatBoostRegressor(depth = 7)
# model = xgb.XGBRegressor()
# model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=300, random_state=rng)
model.fit(x_train, y_train)

pred = model.predict(x_test)

# %%
ind = 0
for i in pos:
    air_df.loc[i, "NOx(GT)"] = pred[ind]
    ind += 1

# %%
air_df[air_df == -200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2773 entries, 0 to 2772
# Data columns (total 12 columns):
# index           0 non-null float64
# Datetime        0 non-null object
# CO(GT)          0 non-null float64
# PT08.S1(CO)     0 non-null float64
# NOx(GT)         0 non-null float64
# PT08.S3(NOx)    0 non-null float64
# NO2(GT)         0 non-null float64
# PT08.S4(NO2)    0 non-null float64
# PT08.S5(O3)     0 non-null float64
# T               0 non-null float64
# RH              0 non-null float64
# AH              0 non-null float64
# dtypes: float64(11), object(1)
# memory usage: 260.0+ KB

# %% [markdown]
# ### Final predict for test dataset

# %%
x_test = air_df[["CO(GT)", "PT08.S1(CO)","NOx(GT)","PT08.S3(NOx)","NO2(GT)","PT08.S4(NO2)","PT08.S5(O3)","T","RH","AH"]].values
pred = final_model.predict(x_test)

# %% [markdown]
# ### Make predicted dataset to submit

# %%
y_pred_df = pd.DataFrame(pred,columns = ['target'])
y_pred_df.to_csv('ridge.csv', index = False)

# %% [markdown]
# ### Checkout approximation

# %%
ans_df = pd.read_csv("ans.csv", sep=';')
ans_df = ans_df['ans']

# %%
ans_df
# Out:
# 0        7.5
# 1        3.8
# 2        3.8
# 3        3.0
# 4        2.8
# 5        2.5
# 6        3.3
# 7        7.0
# 8       18.1
# 9       24.6
# 10      19.7
# 11      13.0
# 12      17.1
# 13      19.3
# 14      28.4
# 15      22.9
# 16      25.7
# 17      26.8
# 18      29.2
# 19      11.9
# 20      10.1
# 21       7.2
# 22       7.1
# 23       7.5
# 24       8.1
# 25       5.5
# 26       5.7
# 27       3.8
# 28       2.9
# 29       2.4
#         ...
# 2743     4.1
# 2744     3.4
# 2745     5.3
# 2746     5.3
# 2747     3.8
# 2748     4.2
# 2749     5.4
# 2750     6.3
# 2751     6.1
# 2752     4.6
# 2753    11.1
# 2754     7.9
# 2755     6.0
# 2756     5.8
# 2757     5.1
# 2758     3.5
# 2759     1.9
# 2760     1.5
# 2761     1.1
# 2762     0.8
# 2763     1.3
# 2764     4.4
# 2765    17.4
# 2766    22.4
# 2767    13.6
# 2768    13.5
# 2769    11.4
# 2770    12.4
# 2771     9.5
# 2772    11.9
# Name: ans, Length: 2773, dtype: float64

# %%
indxs = ans_df[ans_df == -200].index.values
ans_df.drop(ans_df.index[indxs], axis = 0, inplace = True)
ans_df.reset_index()
# Out:
#       index   ans
# 0         0   7.5
# 1         1   3.8
# 2         2   3.8
# 3         3   3.0
# 4         4   2.8
# 5         5   2.5
# 6         6   3.3
# 7         7   7.0
# 8         8  18.1
# 9         9  24.6
# 10       10  19.7
# 11       11  13.0
# 12       12  17.1
# 13       13  19.3
# 14       14  28.4
# 15       15  22.9
# 16       16  25.7
# 17       17  26.8
# 18       18  29.2
# 19       19  11.9
# 20       20  10.1
# 21       21   7.2
# 22       22   7.1
# 23       23   7.5
# 24       24   8.1
# 25       25   5.5
# 26       26   5.7
# 27       27   3.8
# 28       28   2.9
# 29       29   2.4
# ...     ...   ...
# 2743   2743   4.1
# 2744   2744   3.4
# 2745   2745   5.3
# 2746   2746   5.3
# 2747   2747   3.8
# 2748   2748   4.2
# 2749   2749   5.4
# 2750   2750   6.3
# 2751   2751   6.1
# 2752   2752   4.6
# 2753   2753  11.1
# 2754   2754   7.9
# 2755   2755   6.0
# 2756   2756   5.8
# 2757   2757   5.1
# 2758   2758   3.5
# 2759   2759   1.9
# 2760   2760   1.5
# 2761   2761   1.1
# 2762   2762   0.8
# 2763   2763   1.3
# 2764   2764   4.4
# 2765   2765  17.4
# 2766   2766  22.4
# 2767   2767  13.6
# 2768   2768  13.5
# 2769   2769  11.4
# 2770   2770  12.4
# 2771   2771   9.5
# 2772   2772  11.9
#
# [2773 rows x 2 columns]

# %%
predic_df = pd.read_csv("ridge.csv")
predic_df
# Out:
#          target
# 0      5.190749
# 1      0.672473
# 2     -0.110236
# 3      1.504898
# 4     -0.575630
# 5     -1.417497
# 6     -0.000128
# 7      5.214690
# 8     18.284801
# 9     25.131469
# 10    23.134061
# 11    15.140108
# 12    20.215435
# 13    21.155113
# 14    29.630843
# 15    24.709453
# 16    28.358828
# 17    29.020176
# 18    31.538961
# 19    10.986902
# 20     7.737498
# 21     5.307261
# 22     4.855258
# 23     6.212249
# 24     6.617995
# 25     3.604041
# 26     2.960548
# 27     3.566971
# 28     0.394354
# 29    -0.484714
# ...         ...
# 2743   4.263594
# 2744   2.490113
# 2745   3.745912
# 2746   3.608756
# 2747   0.849808
# 2748   0.799975
# 2749   1.508589
# 2750   2.695934
# 2751   3.559831
# 2752   3.494208
# 2753  12.157433
# 2754  10.683444
# 2755   6.579272
# 2756   6.427941
# 2757   4.735020
# 2758   2.102942
# 2759  -0.373853
# 2760  -0.881946
# 2761  -1.718662
# 2762  -1.866803
# 2763  -1.181768
# 2764   3.581489
# 2765  19.655572
# 2766  23.942289
# 2767  17.363282
# 2768  17.081406
# 2769  12.112654
# 2770  10.529137
# 2771   5.946997
# 2772   7.914326
#
# [2773 rows x 1 columns]

# %%
print("RMSE:", mean_squared_error(predic_df, ans_df))
# Out:
# RMSE: 4.988421209910939

# %% [markdown]
# RMSE: 4.359570467231344

# %%
fake = pd.DataFrame(ans_df, columns = ['target'])
fake.to_csv('ridge2.csv', index = False)
